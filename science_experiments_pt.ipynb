# %% [markdown]
# ## Installation

# %%
# !pip install python-terrier
# Out:
# Requirement already satisfied: python-terrier in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (0.10.0)
# Requirement already satisfied: numpy in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (1.26.2)
# Requirement already satisfied: pandas in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (2.1.3)
# Requirement already satisfied: wget in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (3.2)
# Requirement already satisfied: tqdm in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (4.66.1)
# Requirement already satisfied: pyjnius>=1.4.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: matchpy in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: scikit-learn in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (1.3.2)
# Requirement already satisfied: deprecated in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (1.2.14)
# Requirement already satisfied: chest in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: scipy in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (1.11.4)
# Requirement already satisfied: requests in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (1.3.2)
# Requirement already satisfied: nptyping==1.4.4 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (1.4.4)
# Requirement already satisfied: more-itertools in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (10.1.0)
# Requirement already satisfied: ir-datasets>=0.3.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (0.5.5)
# Requirement already satisfied: jinja2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: statsmodels in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (0.14.0)
# Requirement already satisfied: ir-measures>=0.3.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (0.3.3)
# Requirement already satisfied: dill in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (0.3.7)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: typish>=1.7.0 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from nptyping==1.4.4->python-terrier) (1.9.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.12.2)
# Requirement already satisfied: inscriptis>=2.2.0 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (2.3.2)
# Requirement already satisfied: lxml>=4.5.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.9.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (4.3.2)
# Requirement already satisfied: warc3-wet>=0.2.3 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.6)
# Requirement already satisfied: ijson>=3.1.3 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (3.2.3)
# Requirement already satisfied: pyautocorpus>=0.1.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.12)
# Requirement already satisfied: unlzw3>=0.2.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.2)
# Requirement already satisfied: cwl-eval>=1.0.10 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from ir-measures>=0.3.1->python-terrier) (1.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from requests->python-terrier) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from requests->python-terrier) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from requests->python-terrier) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from requests->python-terrier) (2023.11.17)
# Requirement already satisfied: heapdict in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from deprecated->python-terrier) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from jinja2->python-terrier) (2.1.3)
# Requirement already satisfied: multiset<3.0,>=2.0 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from matchpy->python-terrier) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from pandas->python-terrier) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from scikit-learn->python-terrier) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from statsmodels->python-terrier) (23.2)
# Requirement already satisfied: soupsieve>1.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: six in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)

# %%
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: pandas in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (2.1.3)
# Requirement already satisfied: numpy<2,>=1.23.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/gianluca/anaconda3/envs/scrapyenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pyterrier as pt
if not pt.started():
  pt.init()

# %% [markdown]
# ## Science Experiments

# %% [markdown]
# ### Indexing

# %%
import pandas as pd

docs_df = pd.read_json("./science_experiments/experiment_archive.json")

docs_df_2 = pd.read_json("./science_experiments/steve_spangler.json")
docs_df_2 = docs_df_2.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

docs_df = pd.concat([docs_df, docs_df_2], ignore_index=True)
docs_df = docs_df.fillna('')

docno = ['d'+ str(i) for i in range(docs_df.shape[0])]
docs_df['docno'] = docno
docs_df['text'] = docs_df['title'] + ' ' + docs_df['subject'] + ' ' + docs_df['explanation']


exp_title = docs_df.title.values
exp_link = docs_df.link.values
exp_desc = docs_df.description.values
exp_subj = docs_df.subject.values
docs_df
# Out:
#                                   title     subject  \
# 0                          Rainbow milk   Chemistry
# 1                    Egg drop challenge  Technology
# 2                       Cartesian diver     Physics
# 3                       Drops on a coin   Chemistry
# 4                   Homemade marble run     Physics
# ..                                  ...         ...
# 233                    Pop Bottle Music
# 234                       Burning Money
# 235  Pop Rocks Expander (Candy Science)
# 236  Instant Freeze Water - Bottle Slam
# 237          Seven-Layer Density Column
#
#                                            description  \
# 0    Create a color explosion in milk. About polari...
# 1    Build a landing device for an egg and then dro...
# 2    Squeeze the bottle and the matches sink. About...
# 3    How many water drops can fit on a coin? About ...
# 4    Build a marble run on the wall. About gravitat...
# ..                                                 ...
# 233  A popular Las Vegas musical act uses tubes, bo...
# 234  Do you have money burning a hole in your pocke...
# 235  Pop Rocks is one of the greatest candy inventi...
# 236  You put a plastic bottle of soda pop or water ...
# 237  What if you could stack seven different liquid...
#
#                                                   link  \
# 0    https://www.experimentarchive.com/experiments/...
# 1    https://www.experimentarchive.com/experiments/...
# 2    https://www.experimentarchive.com/experiments/...
# 3    https://www.experimentarchive.com/experiments/...
# 4    https://www.experimentarchive.com/experiments/...
# ..                                                 ...
# 233  https://stevespangler.com/experiments/pop-bott...
# 234  https://stevespangler.com/experiments/burning-...
# 235    https://stevespangler.com/experiments/poprocks/
# 236  https://stevespangler.com/experiments/instant-...
# 237  https://stevespangler.com/experiments/seven-la...
#
#                                            explanation docno  \
# 0    Milk is a mixture consisting of water and chem...    d0
# 1    Deformation is a term within physics and techn...    d1
# 2    The head of a match is porous and contains sma...    d2
# 3    Water consists of water molecules that attract...    d3
# 4    The higher up something is, the more gravitati...    d4
# ..                                                 ...   ...
# 233  How Does It Work\nThe science of sound is all ...  d233
# 234  How Does It Work\nBy now you’ve probably guess...  d234
# 235  How Does It Work\nThe secret behind the famous...  d235
# 236  How Does It Work\nYou used salt and ice to dro...  d236
# 237  How Does It Work\nThe science secret here is d...  d237
#
#                                                   text
# 0    Rainbow milk Chemistry Milk is a mixture consi...
# 1    Egg drop challenge Technology Deformation is a...
# 2    Cartesian diver Physics The head of a match is...
# 3    Drops on a coin Chemistry Water consists of wa...
# 4    Homemade marble run Physics The higher up some...
# ..                                                 ...
# 233
# 234
# 235
# 236
# 237
#
# [238 rows x 7 columns]

# %%
indexer = pt.DFIndexer("./index_3docs", overwrite=True)
index_ref = indexer.index(docs_df['text'], docs_df['docno'])
# Out:
# 10:46:00.927 [main] WARN org.terrier.structures.indexing.Indexer - Adding an empty document to the index (d109) - further warnings are suppressed
# 10:46:01.226 [main] WARN org.terrier.structures.indexing.Indexer - Indexed 129 empty documents

# %%
index = pt.IndexFactory.of(index_ref)

for kv in index.getLexicon():
  print("%s  -> %s " % (kv.getKey(), kv.getValue().toString()  ))
# Out:
# 0  -> term632 Nt=9 TF=24 maxTF=10 @{0 0 0}
# 000  -> term348 Nt=7 TF=17 maxTF=6 @{0 9 3}
# 001  -> term1916 Nt=1 TF=1 maxTF=1 @{0 17 7}
# 002  -> term606 Nt=2 TF=2 maxTF=1 @{0 19 5}
# 0025  -> term611 Nt=1 TF=2 maxTF=2 @{0 22 5}
# 01  -> term1250 Nt=1 TF=1 maxTF=1 @{0 24 0}
# 023  -> term2056 Nt=1 TF=2 maxTF=2 @{0 25 4}
# 05  -> term1899 Nt=1 TF=1 maxTF=1 @{0 27 3}
# 063  -> term605 Nt=1 TF=2 maxTF=2 @{0 29 1}
# 079  -> term607 Nt=1 TF=2 maxTF=2 @{0 30 4}
# 096  -> term2038 Nt=1 TF=1 maxTF=1 @{0 31 7}
# 1  -> term211 Nt=20 TF=39 maxTF=8 @{0 33 5}
# 10  -> term310 Nt=7 TF=13 maxTF=4 @{0 49 4}
# 100  -> term1871 Nt=3 TF=5 maxTF=3 @{0 56 4}
# 104  -> term2100 Nt=1 TF=1 maxTF=1 @{0 59 6}
# 106  -> term1315 Nt=1 TF=1 maxTF=1 @{0 61 4}
# 109  -> term1085 Nt=1 TF=1 maxTF=1 @{0 63 0}
# 11  -> term324 Nt=4 TF=5 maxTF=2 @{0 64 4}
# 110  -> term1895 Nt=1 TF=1 maxTF=1 @{0 69 1}
# 11th  -> term795 Nt=1 TF=1 maxTF=1 @{0 70 7}
# 12  -> term1014 Nt=6 TF=9 maxTF=2 @{0 72 1}
# 120  -> term2189 Nt=1 TF=1 maxTF=1 @{0 79 2}
# 121  -> term1234 Nt=1 TF=1 maxTF=1 @{0 81 0}
# 13  -> term839 Nt=2 TF=2 maxTF=1 @{0 82 4}
# 130  -> term1594 Nt=1 TF=1 maxTF=1 @{0 85 0}
# 135  -> term1301 Nt=1 TF=1 maxTF=1 @{0 86 6}
# 14  -> term1313 Nt=1 TF=1 maxTF=1 @{0 88 2}
# 147  -> term1299 Nt=1 TF=1 maxTF=1 @{0 89 6}
# 15  -> term1866 Nt=2 TF=2 maxTF=1 @{0 91 2}
# 150  -> term2192 Nt=1 TF=1 maxTF=1 @{0 93 2}
# 152  -> term1292 Nt=1 TF=1 maxTF=1 @{0 95 0}
# 157  -> term1884 Nt=1 TF=1 maxTF=1 @{0 96 4}
# 165  -> term1287 Nt=1 TF=1 maxTF=1 @{0 98 2}
# 169  -> term1285 Nt=1 TF=1 maxTF=1 @{0 99 6}
# 17th  -> term209 Nt=2 TF=2 maxTF=1 @{0 101 2}
# 1821  -> term1169 Nt=2 TF=2 maxTF=1 @{0 103 0}
# 185  -> term1058 Nt=1 TF=1 maxTF=1 @{0 104 6}
# 18th  -> term779 Nt=2 TF=2 maxTF=1 @{0 106 2}
# 19  -> term1268 Nt=1 TF=1 maxTF=1 @{0 109 0}
# 1916  -> term2160 Nt=1 TF=1 maxTF=1 @{0 110 4}
# 1920  -> term851 Nt=2 TF=2 maxTF=1 @{0 112 2}
# 199  -> term2049 Nt=1 TF=1 maxTF=1 @{0 115 2}
# 1991  -> term1244 Nt=1 TF=1 maxTF=1 @{0 117 0}
# 2  -> term179 Nt=22 TF=46 maxTF=8 @{0 118 4}
# 20  -> term1465 Nt=5 TF=6 maxTF=2 @{0 135 0}
# 200  -> term1832 Nt=1 TF=1 maxTF=1 @{0 140 1}
# 2003  -> term1874 Nt=1 TF=1 maxTF=1 @{0 141 7}
# 2013  -> term1868 Nt=1 TF=1 maxTF=1 @{0 143 5}
# 2015  -> term1337 Nt=1 TF=1 maxTF=1 @{0 145 3}
# 21  -> term1562 Nt=2 TF=2 maxTF=1 @{0 146 7}
# 212  -> term2077 Nt=1 TF=3 maxTF=3 @{0 149 5}
# 22  -> term344 Nt=2 TF=2 maxTF=1 @{0 151 5}
# 228  -> term1330 Nt=1 TF=1 maxTF=1 @{0 154 1}
# 24  -> term1148 Nt=4 TF=4 maxTF=1 @{0 155 5}
# 241  -> term1321 Nt=1 TF=1 maxTF=1 @{0 160 7}
# 25  -> term1262 Nt=1 TF=1 maxTF=1 @{0 162 3}
# 256  -> term1830 Nt=1 TF=1 maxTF=1 @{0 163 7}
# 26  -> term1261 Nt=1 TF=1 maxTF=1 @{0 165 5}
# 265  -> term1311 Nt=1 TF=1 maxTF=1 @{0 167 1}
# 28  -> term1260 Nt=2 TF=2 maxTF=1 @{0 168 5}
# 29  -> term447 Nt=3 TF=4 maxTF=2 @{0 171 1}
# 3  -> term1335 Nt=10 TF=18 maxTF=8 @{0 174 2}
# 30  -> term875 Nt=9 TF=15 maxTF=2 @{0 182 2}
# 311  -> term1269 Nt=1 TF=1 maxTF=1 @{0 191 4}
# 32  -> term1338 Nt=3 TF=10 maxTF=7 @{0 193 0}
# 322  -> term1541 Nt=1 TF=1 maxTF=1 @{0 197 5}
# 328  -> term1865 Nt=1 TF=1 maxTF=1 @{0 199 1}
# 348  -> term1280 Nt=1 TF=1 maxTF=1 @{0 200 7}
# 35  -> term1256 Nt=1 TF=1 maxTF=1 @{0 202 3}
# 356  -> term1028 Nt=1 TF=1 maxTF=1 @{0 203 7}
# 365  -> term2240 Nt=1 TF=1 maxTF=1 @{0 205 3}
# 384  -> term1550 Nt=1 TF=1 maxTF=1 @{0 207 1}
# 39  -> term1754 Nt=1 TF=2 maxTF=2 @{0 208 5}
# 392  -> term1319 Nt=2 TF=3 maxTF=2 @{0 210 4}
# 4  -> term864 Nt=9 TF=14 maxTF=5 @{0 213 5}
# 40  -> term874 Nt=9 TF=9 maxTF=1 @{0 222 2}
# 42  -> term2137 Nt=1 TF=1 maxTF=1 @{0 230 4}
# 437  -> term1284 Nt=1 TF=1 maxTF=1 @{0 232 2}
# 46  -> term1251 Nt=1 TF=2 maxTF=2 @{0 233 6}
# 48  -> term639 Nt=4 TF=4 maxTF=1 @{0 235 3}
# 49  -> term1860 Nt=1 TF=1 maxTF=1 @{0 240 1}
# 4th  -> term756 Nt=1 TF=1 maxTF=1 @{0 241 7}
# 5  -> term169 Nt=12 TF=21 maxTF=6 @{0 243 1}
# 50  -> term1914 Nt=2 TF=3 maxTF=2 @{0 253 0}
# 500  -> term1876 Nt=1 TF=1 maxTF=1 @{0 256 1}
# 52  -> term1255 Nt=1 TF=1 maxTF=1 @{0 257 7}
# 53  -> term1339 Nt=1 TF=1 maxTF=1 @{0 259 3}
# 6  -> term1334 Nt=7 TF=11 maxTF=3 @{0 260 7}
# 60  -> term2187 Nt=1 TF=1 maxTF=1 @{0 268 3}
# 63  -> term629 Nt=1 TF=1 maxTF=1 @{0 270 1}
# 64  -> term1263 Nt=1 TF=1 maxTF=1 @{0 271 3}
# 640  -> term1879 Nt=1 TF=1 maxTF=1 @{0 272 7}
# 646  -> term1239 Nt=1 TF=1 maxTF=1 @{0 274 5}
# 673  -> term1012 Nt=1 TF=1 maxTF=1 @{0 276 1}
# 68  -> term2069 Nt=1 TF=2 maxTF=2 @{0 277 5}
# 684  -> term1309 Nt=1 TF=2 maxTF=2 @{0 279 4}
# 7  -> term1333 Nt=1 TF=3 maxTF=3 @{0 281 1}
# 70  -> term1331 Nt=2 TF=2 maxTF=1 @{0 282 7}
# 72  -> term1402 Nt=2 TF=2 maxTF=1 @{0 285 7}
# 7510  -> term1599 Nt=1 TF=1 maxTF=1 @{0 288 7}
# 77  -> term1328 Nt=1 TF=1 maxTF=1 @{0 290 5}
# 8  -> term862 Nt=3 TF=4 maxTF=2 @{0 292 1}
# 80  -> term2195 Nt=1 TF=1 maxTF=1 @{0 296 2}
# 8040  -> term1591 Nt=1 TF=1 maxTF=1 @{0 298 0}
# 81  -> term1324 Nt=1 TF=1 maxTF=1 @{0 299 6}
# 84  -> term1323 Nt=1 TF=1 maxTF=1 @{0 301 2}
# 85  -> term1057 Nt=1 TF=1 maxTF=1 @{0 302 6}
# 877  -> term2053 Nt=1 TF=1 maxTF=1 @{0 304 2}
# 88  -> term1322 Nt=1 TF=2 maxTF=2 @{0 306 0}
# 9  -> term820 Nt=5 TF=6 maxTF=2 @{0 307 5}
# 93  -> term2063 Nt=1 TF=1 maxTF=1 @{0 313 0}
# 98  -> term1889 Nt=1 TF=1 maxTF=1 @{0 314 6}
# 99  -> term1084 Nt=1 TF=1 maxTF=1 @{0 316 4}
# abil  -> term520 Nt=7 TF=8 maxTF=2 @{0 318 0}
# abl  -> term829 Nt=7 TF=7 maxTF=1 @{0 325 3}
# absorb  -> term885 Nt=15 TF=29 maxTF=8 @{0 331 7}
# acceler  -> term872 Nt=1 TF=1 maxTF=1 @{0 344 7}
# accept  -> term834 Nt=1 TF=1 maxTF=1 @{0 346 1}
# accid  -> term1735 Nt=1 TF=1 maxTF=1 @{0 347 3}
# accord  -> term769 Nt=6 TF=6 maxTF=1 @{0 349 1}
# accumul  -> term1217 Nt=3 TF=3 maxTF=1 @{0 355 3}
# accur  -> term1213 Nt=2 TF=2 maxTF=1 @{0 359 3}
# accustom  -> term754 Nt=1 TF=1 maxTF=1 @{0 362 3}
# acet  -> term288 Nt=3 TF=8 maxTF=3 @{0 363 5}
# aceton  -> term1698 Nt=2 TF=20 maxTF=18 @{0 368 0}
# achiev  -> term383 Nt=2 TF=2 maxTF=1 @{0 373 0}
# achil  -> term687 Nt=1 TF=1 maxTF=1 @{0 375 2}
# acid  -> term276 Nt=8 TF=25 maxTF=7 @{0 376 4}
# across  -> term1357 Nt=3 TF=3 maxTF=1 @{0 386 7}
# act  -> term84 Nt=10 TF=12 maxTF=2 @{0 390 3}
# action  -> term2185 Nt=2 TF=2 maxTF=1 @{0 397 7}
# activ  -> term2186 Nt=1 TF=1 maxTF=1 @{0 399 7}
# actual  -> term501 Nt=25 TF=28 maxTF=2 @{0 401 5}
# ad  -> term64 Nt=9 TF=12 maxTF=2 @{0 417 0}
# adapt  -> term1531 Nt=1 TF=1 maxTF=1 @{0 424 7}
# add  -> term570 Nt=11 TF=15 maxTF=2 @{0 426 3}
# addit  -> term471 Nt=11 TF=13 maxTF=2 @{0 435 7}
# adult  -> term1497 Nt=1 TF=1 maxTF=1 @{0 445 5}
# advanc  -> term2015 Nt=1 TF=1 maxTF=1 @{0 447 1}
# advantag  -> term529 Nt=3 TF=3 maxTF=1 @{0 448 7}
# advic  -> term1520 Nt=1 TF=1 maxTF=1 @{0 452 1}
# aerosol  -> term2209 Nt=1 TF=1 maxTF=1 @{0 453 5}
# affect  -> term1032 Nt=7 TF=8 maxTF=2 @{0 455 3}
# ag  -> term1463 Nt=1 TF=4 maxTF=4 @{0 461 2}
# agent  -> term2130 Nt=1 TF=1 maxTF=1 @{0 463 1}
# aggreg  -> term18 Nt=1 TF=1 maxTF=1 @{0 464 7}
# ago  -> term848 Nt=2 TF=3 maxTF=2 @{0 465 1}
# agricultur  -> term1859 Nt=1 TF=1 maxTF=1 @{0 468 0}
# air  -> term199 Nt=59 TF=434 maxTF=34 @{0 469 6}
# aircraft  -> term966 Nt=1 TF=8 maxTF=8 @{0 538 7}
# airplan  -> term961 Nt=1 TF=1 maxTF=1 @{0 541 0}
# airtight  -> term2050 Nt=1 TF=4 maxTF=4 @{0 542 2}
# albert  -> term1816 Nt=1 TF=1 maxTF=1 @{0 544 3}
# alcohol  -> term1194 Nt=2 TF=6 maxTF=4 @{0 546 1}
# alien  -> term2162 Nt=1 TF=1 maxTF=1 @{0 549 5}
# alkan  -> term2221 Nt=1 TF=4 maxTF=4 @{0 551 3}
# allow  -> term242 Nt=5 TF=5 maxTF=1 @{0 553 4}
# alon  -> term1959 Nt=1 TF=1 maxTF=1 @{0 558 4}
# alter  -> term668 Nt=1 TF=1 maxTF=1 @{0 560 2}
# altern  -> term1135 Nt=4 TF=7 maxTF=3 @{0 561 4}
# altitud  -> term2086 Nt=1 TF=1 maxTF=1 @{0 566 7}
# alum  -> term2009 Nt=1 TF=7 maxTF=7 @{0 568 5}
# aluminum  -> term2000 Nt=2 TF=11 maxTF=10 @{0 571 1}
# amaz  -> term1281 Nt=2 TF=2 maxTF=1 @{0 574 6}
# ambient  -> term1524 Nt=2 TF=2 maxTF=1 @{0 577 6}
# amount  -> term361 Nt=21 TF=29 maxTF=3 @{0 580 0}
# amplifi  -> term2141 Nt=1 TF=1 maxTF=1 @{0 595 0}
# analog  -> term827 Nt=1 TF=2 maxTF=2 @{0 596 6}
# analysi  -> term2228 Nt=1 TF=1 maxTF=1 @{0 598 1}
# anatomi  -> term1498 Nt=1 TF=2 maxTF=2 @{0 599 7}
# ancestor  -> term686 Nt=2 TF=3 maxTF=2 @{0 601 4}
# ancient  -> term752 Nt=2 TF=2 maxTF=1 @{0 604 3}
# angl  -> term1430 Nt=3 TF=4 maxTF=2 @{0 607 1}
# ankl  -> term666 Nt=1 TF=1 maxTF=1 @{0 611 0}
# answer  -> term95 Nt=53 TF=99 maxTF=3 @{0 612 2}
# antarctica  -> term1912 Nt=1 TF=1 maxTF=1 @{0 640 4}
# anthocyanin  -> term1978 Nt=1 TF=3 maxTF=3 @{0 642 2}
# anymor  -> term427 Nt=6 TF=6 maxTF=1 @{0 644 2}
# anywai  -> term1152 Nt=1 TF=1 maxTF=1 @{0 649 4}
# appear  -> term2032 Nt=2 TF=2 maxTF=1 @{0 651 0}
# appli  -> term124 Nt=2 TF=2 maxTF=1 @{0 653 0}
# approach  -> term1801 Nt=1 TF=1 maxTF=1 @{0 655 2}
# approxim  -> term1176 Nt=5 TF=5 maxTF=1 @{0 657 0}
# aq  -> term1784 Nt=1 TF=2 maxTF=2 @{0 662 0}
# arc  -> term1178 Nt=2 TF=2 maxTF=1 @{0 663 7}
# arch  -> term1930 Nt=1 TF=1 maxTF=1 @{0 665 5}
# archaea  -> term1202 Nt=1 TF=1 maxTF=1 @{0 667 3}
# archimed  -> term1941 Nt=1 TF=1 maxTF=1 @{0 668 7}
# arctic  -> term2242 Nt=1 TF=4 maxTF=4 @{0 670 5}
# area  -> term47 Nt=13 TF=19 maxTF=3 @{0 672 6}
# argon  -> term594 Nt=2 TF=2 maxTF=1 @{0 682 6}
# argument  -> term1814 Nt=1 TF=1 maxTF=1 @{0 685 6}
# aris  -> term9 Nt=15 TF=17 maxTF=2 @{0 687 4}
# aristotl  -> term1551 Nt=1 TF=4 maxTF=4 @{0 699 0}
# arm  -> term1544 Nt=1 TF=1 maxTF=1 @{0 700 7}
# armand  -> term794 Nt=1 TF=1 maxTF=1 @{0 702 3}
# aros  -> term252 Nt=2 TF=2 maxTF=1 @{0 703 5}
# arout  -> term1911 Nt=1 TF=1 maxTF=1 @{0 705 3}
# arrang  -> term1002 Nt=2 TF=4 maxTF=2 @{0 707 1}
# articl  -> term1923 Nt=1 TF=1 maxTF=1 @{0 710 3}
# ask  -> term755 Nt=5 TF=5 maxTF=1 @{0 712 1}
# assembl  -> term1230 Nt=2 TF=6 maxTF=3 @{0 717 1}
# assign  -> term1924 Nt=1 TF=1 maxTF=1 @{0 720 5}
# assist  -> term1861 Nt=1 TF=1 maxTF=1 @{0 722 3}
# assum  -> term1896 Nt=1 TF=1 maxTF=1 @{0 724 1}
# asteroid  -> term1425 Nt=1 TF=4 maxTF=4 @{0 725 7}
# astronom  -> term835 Nt=2 TF=3 maxTF=2 @{0 727 6}
# astronomi  -> term470 Nt=11 TF=12 maxTF=2 @{0 730 3}
# at  -> term793 Nt=1 TF=1 maxTF=1 @{0 740 4}
# atmospher  -> term339 Nt=17 TF=50 maxTF=9 @{0 741 6}
# atom  -> term129 Nt=25 TF=73 maxTF=19 @{0 757 3}
# attach  -> term7 Nt=8 TF=11 maxTF=2 @{0 777 7}
# attent  -> term2064 Nt=1 TF=1 maxTF=1 @{0 785 2}
# attract  -> term15 Nt=17 TF=33 maxTF=3 @{0 787 0}
# attribut  -> term790 Nt=1 TF=1 maxTF=1 @{0 801 0}
# auriga  -> term1664 Nt=1 TF=1 maxTF=1 @{0 802 2}
# australia  -> term1593 Nt=1 TF=1 maxTF=1 @{0 804 0}
# author  -> term175 Nt=1 TF=1 maxTF=1 @{0 805 6}
# automat  -> term1934 Nt=1 TF=1 maxTF=1 @{0 806 2}
# autumn  -> term1985 Nt=2 TF=5 maxTF=3 @{0 808 0}
# averag  -> term1538 Nt=4 TF=4 maxTF=1 @{0 811 3}
# avoid  -> term389 Nt=5 TF=5 maxTF=1 @{0 815 5}
# awai  -> term81 Nt=29 TF=38 maxTF=4 @{0 820 5}
# awar  -> term660 Nt=1 TF=1 maxTF=1 @{0 838 0}
# axi  -> term1214 Nt=2 TF=4 maxTF=3 @{0 839 2}
# babi  -> term1485 Nt=1 TF=4 maxTF=4 @{0 842 4}
# back  -> term245 Nt=18 TF=23 maxTF=3 @{0 844 3}
# background  -> term2051 Nt=1 TF=1 maxTF=1 @{0 856 6}
# backward  -> term1825 Nt=3 TF=5 maxTF=3 @{0 858 4}
# bacteri  -> term1792 Nt=1 TF=1 maxTF=1 @{0 862 4}
# bacteria  -> term627 Nt=5 TF=16 maxTF=11 @{0 864 2}
# bad  -> term151 Nt=4 TF=4 maxTF=1 @{0 871 7}
# bag  -> term947 Nt=5 TF=20 maxTF=11 @{0 875 3}
# bake  -> term882 Nt=5 TF=37 maxTF=14 @{0 883 0}
# balanc  -> term927 Nt=2 TF=3 maxTF=2 @{0 892 4}
# ball  -> term317 Nt=6 TF=19 maxTF=11 @{0 895 5}
# balloon  -> term402 Nt=9 TF=86 maxTF=18 @{0 904 0}
# band  -> term951 Nt=2 TF=4 maxTF=3 @{0 921 3}
# bang  -> term823 Nt=2 TF=3 maxTF=2 @{0 924 1}
# bar  -> term1243 Nt=2 TF=14 maxTF=7 @{0 927 2}
# bare  -> term2078 Nt=1 TF=1 maxTF=1 @{0 931 6}
# barrier  -> term1346 Nt=2 TF=2 maxTF=1 @{0 933 4}
# bartholomew  -> term1382 Nt=1 TF=1 maxTF=1 @{0 936 0}
# base  -> term931 Nt=1 TF=4 maxTF=4 @{0 937 4}
# bath  -> term2252 Nt=1 TF=1 maxTF=1 @{0 939 1}
# batteri  -> term653 Nt=3 TF=4 maxTF=2 @{0 940 7}
# bc  -> term1553 Nt=2 TF=2 maxTF=1 @{0 943 6}
# be  -> term143 Nt=24 TF=30 maxTF=5 @{0 946 0}
# beacus  -> term2123 Nt=1 TF=1 maxTF=1 @{0 961 4}
# bean  -> term1134 Nt=1 TF=1 maxTF=1 @{0 963 2}
# bear  -> term1021 Nt=2 TF=10 maxTF=5 @{0 964 6}
# beat  -> term2196 Nt=1 TF=3 maxTF=3 @{0 969 0}
# beauti  -> term1962 Nt=3 TF=3 maxTF=1 @{0 971 0}
# bedrock  -> term615 Nt=2 TF=2 maxTF=1 @{0 974 2}
# began  -> term871 Nt=4 TF=4 maxTF=1 @{0 977 0}
# begin  -> term530 Nt=23 TF=31 maxTF=4 @{0 981 0}
# behav  -> term1376 Nt=3 TF=5 maxTF=3 @{0 995 4}
# belief  -> term1302 Nt=1 TF=1 maxTF=1 @{0 999 2}
# believ  -> term984 Nt=2 TF=2 maxTF=1 @{0 1000 6}
# belong  -> term715 Nt=2 TF=2 maxTF=1 @{0 1003 4}
# bend  -> term586 Nt=10 TF=11 maxTF=2 @{0 1006 0}
# bernouil  -> term962 Nt=4 TF=6 maxTF=2 @{0 1014 7}
# best  -> term109 Nt=9 TF=12 maxTF=3 @{0 1019 3}
# beta  -> term1972 Nt=1 TF=1 maxTF=1 @{0 1026 6}
# bicarbon  -> term884 Nt=4 TF=7 maxTF=4 @{0 1028 4}
# big  -> term869 Nt=11 TF=13 maxTF=3 @{0 1033 5}
# bigger  -> term1588 Nt=4 TF=4 maxTF=1 @{0 1042 5}
# biggest  -> term1343 Nt=1 TF=1 maxTF=1 @{0 1046 7}
# bill  -> term1662 Nt=1 TF=4 maxTF=4 @{0 1048 3}
# billion  -> term858 Nt=2 TF=4 maxTF=3 @{0 1050 4}
# bind  -> term1150 Nt=2 TF=2 maxTF=1 @{0 1053 4}
# biologi  -> term296 Nt=15 TF=15 maxTF=1 @{0 1056 2}
# bit  -> term213 Nt=12 TF=12 maxTF=1 @{0 1069 0}
# black  -> term2156 Nt=2 TF=3 maxTF=2 @{0 1078 4}
# blind  -> term706 Nt=1 TF=1 maxTF=1 @{0 1081 1}
# blink  -> term704 Nt=1 TF=3 maxTF=3 @{0 1082 3}
# block  -> term2028 Nt=2 TF=3 maxTF=2 @{0 1083 7}
# blood  -> term2199 Nt=1 TF=12 maxTF=12 @{0 1086 0}
# blow  -> term487 Nt=10 TF=18 maxTF=4 @{0 1089 1}
# blown  -> term565 Nt=1 TF=1 maxTF=1 @{0 1098 7}
# blue  -> term1965 Nt=1 TF=3 maxTF=3 @{0 1099 7}
# blur  -> term696 Nt=1 TF=1 maxTF=1 @{0 1101 7}
# boat  -> term1607 Nt=1 TF=8 maxTF=8 @{0 1103 1}
# bodi  -> term132 Nt=16 TF=58 maxTF=10 @{0 1105 6}
# boi  -> term1366 Nt=1 TF=1 maxTF=1 @{0 1122 0}
# boil  -> term1358 Nt=9 TF=53 maxTF=39 @{0 1123 4}
# boilingth  -> term2091 Nt=1 TF=1 maxTF=1 @{0 1137 2}
# boilsth  -> term2083 Nt=1 TF=1 maxTF=1 @{0 1139 0}
# boilswhen  -> term2073 Nt=1 TF=1 maxTF=1 @{0 1140 6}
# bomb  -> term1444 Nt=1 TF=1 maxTF=1 @{0 1142 4}
# bombard  -> term1891 Nt=1 TF=1 maxTF=1 @{0 1144 0}
# bond  -> term33 Nt=13 TF=28 maxTF=6 @{0 1145 6}
# bone  -> term282 Nt=1 TF=13 maxTF=13 @{0 1157 1}
# book  -> term1371 Nt=2 TF=2 maxTF=1 @{0 1159 3}
# bore  -> term1059 Nt=1 TF=1 maxTF=1 @{0 1162 1}
# botanist  -> term1824 Nt=1 TF=1 maxTF=1 @{0 1163 5}
# bottl  -> term181 Nt=16 TF=159 maxTF=31 @{0 1165 3}
# bottom  -> term429 Nt=11 TF=23 maxTF=5 @{0 1194 4}
# bought  -> term1072 Nt=1 TF=1 maxTF=1 @{0 1204 4}
# bounc  -> term812 Nt=5 TF=7 maxTF=2 @{0 1206 0}
# bound  -> term2194 Nt=2 TF=3 maxTF=2 @{0 1211 4}
# boundari  -> term2144 Nt=1 TF=1 maxTF=1 @{0 1214 1}
# bowl  -> term513 Nt=9 TF=17 maxTF=6 @{0 1215 7}
# box  -> term2029 Nt=3 TF=4 maxTF=2 @{0 1224 7}
# brain  -> term522 Nt=8 TF=13 maxTF=4 @{0 1228 2}
# branch  -> term1948 Nt=1 TF=1 maxTF=1 @{0 1236 1}
# brand  -> term1707 Nt=1 TF=2 maxTF=2 @{0 1237 7}
# bread  -> term2108 Nt=2 TF=2 maxTF=1 @{0 1239 6}
# break  -> term60 Nt=20 TF=38 maxTF=4 @{0 1242 2}
# breath  -> term903 Nt=1 TF=5 maxTF=5 @{0 1257 2}
# bridg  -> term1927 Nt=1 TF=15 maxTF=15 @{0 1259 0}
# bright  -> term734 Nt=1 TF=1 maxTF=1 @{0 1262 4}
# brighter  -> term1308 Nt=2 TF=2 maxTF=1 @{0 1263 6}
# brightli  -> term1254 Nt=1 TF=1 maxTF=1 @{0 1266 4}
# bring  -> term547 Nt=2 TF=2 maxTF=1 @{0 1268 0}
# broke  -> term414 Nt=1 TF=1 maxTF=1 @{0 1270 6}
# broken  -> term1352 Nt=3 TF=5 maxTF=3 @{0 1271 6}
# brown  -> term1818 Nt=1 TF=1 maxTF=1 @{0 1275 6}
# brownian  -> term1809 Nt=1 TF=4 maxTF=4 @{0 1277 4}
# brownish  -> term609 Nt=1 TF=1 maxTF=1 @{0 1279 5}
# brush  -> term1379 Nt=1 TF=1 maxTF=1 @{0 1280 7}
# bubbl  -> term613 Nt=13 TF=92 maxTF=28 @{0 1282 3}
# bubblesit  -> term2048 Nt=1 TF=1 maxTF=1 @{0 1303 0}
# bucket  -> term58 Nt=3 TF=3 maxTF=1 @{0 1304 6}
# bud  -> term2104 Nt=1 TF=1 maxTF=1 @{0 1307 6}
# budget  -> term1925 Nt=1 TF=1 maxTF=1 @{0 1309 4}
# bui  -> term1640 Nt=2 TF=2 maxTF=1 @{0 1311 2}
# build  -> term86 Nt=5 TF=15 maxTF=5 @{0 1314 4}
# built  -> term166 Nt=15 TF=16 maxTF=2 @{0 1319 6}
# bulb  -> term353 Nt=1 TF=1 maxTF=1 @{0 1330 7}
# bulg  -> term1513 Nt=1 TF=1 maxTF=1 @{0 1331 7}
# bulk  -> term441 Nt=1 TF=1 maxTF=1 @{0 1333 3}
# bump  -> term733 Nt=1 TF=1 maxTF=1 @{0 1334 3}
# bumpi  -> term2149 Nt=1 TF=1 maxTF=1 @{0 1335 5}
# bunch  -> term50 Nt=3 TF=3 maxTF=1 @{0 1337 3}
# bundl  -> term671 Nt=2 TF=3 maxTF=2 @{0 1340 3}
# buoyanc  -> term1945 Nt=1 TF=4 maxTF=4 @{0 1343 0}
# burn  -> term504 Nt=18 TF=63 maxTF=8 @{0 1345 1}
# burst  -> term1165 Nt=3 TF=6 maxTF=3 @{0 1362 2}
# butan  -> term2223 Nt=1 TF=6 maxTF=6 @{0 1365 7}
# byzantin  -> term782 Nt=1 TF=1 maxTF=1 @{0 1368 2}
# c2h3o2  -> term1791 Nt=1 TF=1 maxTF=1 @{0 1369 4}
# c2h5oh  -> term1652 Nt=3 TF=3 maxTF=1 @{0 1371 2}
# c3h6o  -> term1685 Nt=1 TF=1 maxTF=1 @{0 1374 2}
# c6h12o6  -> term1732 Nt=1 TF=2 maxTF=2 @{0 1376 0}
# c8h8  -> term1713 Nt=1 TF=1 maxTF=1 @{0 1377 7}
# ca  -> term1783 Nt=1 TF=1 maxTF=1 @{0 1379 5}
# cabin  -> term337 Nt=1 TF=1 maxTF=1 @{0 1381 3}
# cabl  -> term381 Nt=2 TF=3 maxTF=2 @{0 1382 1}
# caco3  -> term1780 Nt=1 TF=2 maxTF=2 @{0 1384 6}
# cake  -> term1571 Nt=2 TF=2 maxTF=1 @{0 1386 5}
# calcif  -> term277 Nt=1 TF=1 maxTF=1 @{0 1389 5}
# calcium  -> term299 Nt=2 TF=7 maxTF=4 @{0 1390 3}
# calf  -> term699 Nt=1 TF=1 maxTF=1 @{0 1393 4}
# call  -> term53 Nt=48 TF=80 maxTF=4 @{0 1394 6}
# callistodiamet  -> term1310 Nt=1 TF=1 maxTF=1 @{0 1419 6}
# came  -> term1062 Nt=6 TF=7 maxTF=2 @{0 1421 2}
# can  -> term23 Nt=85 TF=344 maxTF=26 @{0 1427 1}
# canberra  -> term1882 Nt=1 TF=1 maxTF=1 @{0 1486 0}
# candi  -> term2255 Nt=1 TF=1 maxTF=1 @{0 1487 6}
# candl  -> term550 Nt=9 TF=50 maxTF=13 @{0 1489 4}
# canin  -> term1482 Nt=1 TF=3 maxTF=3 @{0 1502 1}
# canist  -> term881 Nt=1 TF=5 maxTF=5 @{0 1503 7}
# cannon  -> term2176 Nt=1 TF=1 maxTF=1 @{0 1505 5}
# cap  -> term1578 Nt=2 TF=16 maxTF=15 @{0 1507 3}
# capac  -> term924 Nt=4 TF=6 maxTF=3 @{0 1511 7}
# capillari  -> term560 Nt=2 TF=2 maxTF=1 @{0 1516 5}
# captur  -> term595 Nt=3 TF=3 maxTF=1 @{0 1519 3}
# car  -> term107 Nt=4 TF=4 maxTF=1 @{0 1523 3}
# carbon  -> term568 Nt=20 TF=84 maxTF=21 @{0 1527 3}
# cardin  -> term785 Nt=1 TF=2 maxTF=2 @{0 1548 1}
# caroten  -> term1946 Nt=1 TF=1 maxTF=1 @{0 1549 4}
# carotenoid  -> term1950 Nt=1 TF=4 maxTF=4 @{0 1551 2}
# carpet  -> term1422 Nt=1 TF=1 maxTF=1 @{0 1553 3}
# carri  -> term952 Nt=3 TF=3 maxTF=1 @{0 1554 7}
# carrot  -> term1975 Nt=1 TF=1 maxTF=1 @{0 1558 7}
# cartesian  -> term173 Nt=1 TF=1 maxTF=1 @{0 1560 5}
# case  -> term583 Nt=19 TF=23 maxTF=2 @{0 1561 1}
# cassiopeia  -> term1676 Nt=1 TF=1 maxTF=1 @{0 1574 1}
# cast  -> term466 Nt=2 TF=3 maxTF=2 @{0 1575 7}
# catch  -> term2126 Nt=1 TF=1 maxTF=1 @{0 1578 6}
# caus  -> term48 Nt=32 TF=44 maxTF=3 @{0 1580 4}
# caviti  -> term1956 Nt=2 TF=6 maxTF=4 @{0 1597 6}
# cd  -> term1686 Nt=2 TF=11 maxTF=10 @{0 1600 4}
# ceil  -> term2139 Nt=1 TF=1 maxTF=1 @{0 1604 5}
# celesti  -> term1316 Nt=3 TF=11 maxTF=6 @{0 1606 3}
# cell  -> term525 Nt=10 TF=55 maxTF=17 @{0 1611 1}
# cellulos  -> term1919 Nt=1 TF=1 maxTF=1 @{0 1626 0}
# center  -> term379 Nt=6 TF=10 maxTF=4 @{0 1627 6}
# central  -> term928 Nt=1 TF=1 maxTF=1 @{0 1634 0}
# centuri  -> term214 Nt=3 TF=6 maxTF=4 @{0 1635 2}
# cerevisia  -> term2099 Nt=1 TF=2 maxTF=2 @{0 1638 7}
# ch3cooh  -> term1794 Nt=1 TF=1 maxTF=1 @{0 1640 6}
# chain  -> term2173 Nt=1 TF=2 maxTF=2 @{0 1642 4}
# challeng  -> term123 Nt=1 TF=1 maxTF=1 @{0 1644 3}
# chanc  -> term1418 Nt=5 TF=5 maxTF=1 @{0 1644 7}
# chang  -> term139 Nt=32 TF=85 maxTF=8 @{0 1649 5}
# channel  -> term1762 Nt=1 TF=1 maxTF=1 @{0 1671 6}
# character  -> term134 Nt=2 TF=2 maxTF=1 @{0 1673 4}
# characterist  -> term1199 Nt=1 TF=1 maxTF=1 @{0 1675 6}
# charg  -> term20 Nt=12 TF=64 maxTF=12 @{0 1677 2}
# check  -> term1631 Nt=1 TF=1 maxTF=1 @{0 1693 0}
# chemic  -> term37 Nt=37 TF=114 maxTF=10 @{0 1694 6}
# chemistri  -> term22 Nt=25 TF=29 maxTF=3 @{0 1723 5}
# chew  -> term1493 Nt=1 TF=2 maxTF=2 @{0 1740 1}
# chicken  -> term280 Nt=1 TF=2 maxTF=2 @{0 1741 6}
# child  -> term904 Nt=1 TF=1 maxTF=1 @{0 1742 5}
# children  -> term1359 Nt=1 TF=1 maxTF=1 @{0 1743 7}
# chimnei  -> term1838 Nt=1 TF=1 maxTF=1 @{0 1745 3}
# chip  -> term1341 Nt=1 TF=1 maxTF=1 @{0 1747 1}
# chlorat  -> term1026 Nt=1 TF=2 maxTF=2 @{0 1748 5}
# chlorid  -> term1031 Nt=2 TF=4 maxTF=3 @{0 1750 2}
# chlorin  -> term1004 Nt=1 TF=1 maxTF=1 @{0 1753 4}
# chlorophyl  -> term1957 Nt=1 TF=9 maxTF=9 @{0 1755 0}
# choos  -> term1933 Nt=4 TF=4 maxTF=1 @{0 1757 6}
# chosen  -> term1795 Nt=1 TF=1 maxTF=1 @{0 1761 4}
# chromatin  -> term1210 Nt=1 TF=3 maxTF=3 @{0 1763 2}
# chromatographi  -> term1963 Nt=1 TF=5 maxTF=5 @{0 1765 0}
# cinnamon  -> term1426 Nt=1 TF=2 maxTF=2 @{0 1767 2}
# circl  -> term2237 Nt=1 TF=4 maxTF=4 @{0 1768 7}
# circuit  -> term663 Nt=3 TF=3 maxTF=1 @{0 1771 0}
# circular  -> term1253 Nt=1 TF=1 maxTF=1 @{0 1773 6}
# cl2  -> term1010 Nt=1 TF=1 maxTF=1 @{0 1775 2}
# clai  -> term580 Nt=3 TF=5 maxTF=3 @{0 1776 6}
# classic  -> term1540 Nt=1 TF=1 maxTF=1 @{0 1780 2}
# classifi  -> term355 Nt=2 TF=4 maxTF=2 @{0 1781 6}
# clean  -> term1157 Nt=2 TF=3 maxTF=2 @{0 1784 4}
# cleans  -> term1270 Nt=1 TF=1 maxTF=1 @{0 1787 1}
# clear  -> term270 Nt=5 TF=8 maxTF=3 @{0 1788 5}
# clearer  -> term2138 Nt=1 TF=1 maxTF=1 @{0 1794 4}
# clearli  -> term585 Nt=3 TF=3 maxTF=1 @{0 1796 2}
# close  -> term645 Nt=17 TF=22 maxTF=3 @{0 1800 2}
# closer  -> term1111 Nt=11 TF=11 maxTF=1 @{0 1811 7}
# closest  -> term2116 Nt=1 TF=1 maxTF=1 @{0 1820 1}
# cloth  -> term1367 Nt=3 TF=7 maxTF=3 @{0 1821 7}
# cloud  -> term1106 Nt=8 TF=29 maxTF=7 @{0 1824 5}
# clump  -> term1041 Nt=3 TF=4 maxTF=2 @{0 1834 4}
# cluster  -> term868 Nt=2 TF=7 maxTF=5 @{0 1838 3}
# cm  -> term1100 Nt=2 TF=8 maxTF=7 @{0 1841 6}
# co2  -> term1027 Nt=6 TF=6 maxTF=1 @{0 1845 0}
# coagul  -> term1035 Nt=1 TF=2 maxTF=2 @{0 1850 0}
# coal  -> term1741 Nt=1 TF=1 maxTF=1 @{0 1851 5}
# coconut  -> term1128 Nt=1 TF=1 maxTF=1 @{0 1853 3}
# code  -> term1193 Nt=1 TF=3 maxTF=3 @{0 1854 7}
# coffe  -> term1394 Nt=1 TF=1 maxTF=1 @{0 1856 5}
# coher  -> term1942 Nt=1 TF=1 maxTF=1 @{0 1858 1}
# coil  -> term648 Nt=1 TF=4 maxTF=4 @{0 1859 7}
# coin  -> term229 Nt=1 TF=3 maxTF=3 @{0 1861 4}
# coke  -> term1560 Nt=1 TF=1 maxTF=1 @{0 1862 4}
# cold  -> term502 Nt=22 TF=51 maxTF=7 @{0 1864 0}
# colder  -> term892 Nt=6 TF=7 maxTF=2 @{0 1881 3}
# collaps  -> term1238 Nt=2 TF=2 maxTF=1 @{0 1888 0}
# collect  -> term976 Nt=6 TF=9 maxTF=3 @{0 1891 0}
# collector  -> term1908 Nt=1 TF=1 maxTF=1 @{0 1897 3}
# collid  -> term88 Nt=24 TF=37 maxTF=5 @{0 1899 1}
# collis  -> term168 Nt=8 TF=20 maxTF=5 @{0 1913 4}
# color  -> term14 Nt=11 TF=50 maxTF=11 @{0 1921 0}
# colorless  -> term1717 Nt=1 TF=1 maxTF=1 @{0 1934 5}
# column  -> term316 Nt=6 TF=14 maxTF=4 @{0 1936 3}
# comb  -> term977 Nt=1 TF=1 maxTF=1 @{0 1943 3}
# combust  -> term541 Nt=6 TF=14 maxTF=4 @{0 1944 7}
# come  -> term309 Nt=25 TF=43 maxTF=6 @{0 1951 3}
# comet  -> term1428 Nt=2 TF=5 maxTF=4 @{0 1967 5}
# common  -> term112 Nt=16 TF=24 maxTF=5 @{0 1971 0}
# compact  -> term1728 Nt=1 TF=1 maxTF=1 @{0 1983 0}
# compar  -> term35 Nt=17 TF=20 maxTF=2 @{0 1984 6}
# compass  -> term1001 Nt=3 TF=4 maxTF=2 @{0 1996 3}
# compens  -> term1943 Nt=1 TF=1 maxTF=1 @{0 1999 2}
# complement  -> term1796 Nt=1 TF=1 maxTF=1 @{0 2001 0}
# complet  -> term554 Nt=19 TF=30 maxTF=4 @{0 2002 6}
# complic  -> term307 Nt=2 TF=2 maxTF=1 @{0 2017 1}
# compon  -> term304 Nt=3 TF=4 maxTF=2 @{0 2019 5}
# compos  -> term1699 Nt=3 TF=4 maxTF=2 @{0 2023 4}
# composit  -> term813 Nt=3 TF=3 maxTF=1 @{0 2026 3}
# compound  -> term1805 Nt=1 TF=1 maxTF=1 @{0 2030 1}
# compress  -> term186 Nt=9 TF=13 maxTF=2 @{0 2031 7}
# concentr  -> term1018 Nt=5 TF=5 maxTF=1 @{0 2039 7}
# concert  -> term2080 Nt=1 TF=1 maxTF=1 @{0 2045 5}
# conclus  -> term1907 Nt=1 TF=1 maxTF=1 @{0 2047 3}
# condens  -> term1108 Nt=8 TF=25 maxTF=7 @{0 2049 1}
# conduct  -> term1191 Nt=6 TF=21 maxTF=8 @{0 2058 4}
# conductor  -> term1420 Nt=4 TF=4 maxTF=1 @{0 2066 1}
# cone  -> term2164 Nt=1 TF=1 maxTF=1 @{0 2070 1}
# confid  -> term2089 Nt=1 TF=1 maxTF=1 @{0 2071 7}
# configur  -> term1994 Nt=2 TF=2 maxTF=1 @{0 2073 5}
# confin  -> term1569 Nt=2 TF=2 maxTF=1 @{0 2076 3}
# confirm  -> term1291 Nt=1 TF=1 maxTF=1 @{0 2078 1}
# confus  -> term2031 Nt=1 TF=1 maxTF=1 @{0 2079 5}
# connect  -> term306 Nt=6 TF=10 maxTF=3 @{0 2081 3}
# consequ  -> term1769 Nt=1 TF=1 maxTF=1 @{0 2088 1}
# consid  -> term1123 Nt=7 TF=7 maxTF=1 @{0 2089 7}
# consist  -> term39 Nt=51 TF=82 maxTF=4 @{0 2096 1}
# constant  -> term1527 Nt=1 TF=1 maxTF=1 @{0 2122 2}
# constantli  -> term225 Nt=13 TF=13 maxTF=1 @{0 2123 6}
# constel  -> term82 Nt=2 TF=6 maxTF=5 @{0 2133 2}
# constitu  -> term527 Nt=9 TF=9 maxTF=1 @{0 2135 6}
# constitut  -> term1935 Nt=2 TF=2 maxTF=1 @{0 2142 4}
# construct  -> term377 Nt=3 TF=3 maxTF=1 @{0 2144 6}
# consum  -> term741 Nt=4 TF=4 maxTF=1 @{0 2148 6}
# contact  -> term1020 Nt=19 TF=32 maxTF=4 @{0 2153 6}
# contain  -> term215 Nt=27 TF=49 maxTF=8 @{0 2166 5}
# content  -> term1132 Nt=5 TF=6 maxTF=2 @{0 2184 5}
# context  -> term2174 Nt=1 TF=1 maxTF=1 @{0 2190 0}
# continent  -> term1445 Nt=1 TF=1 maxTF=1 @{0 2191 6}
# continu  -> term866 Nt=7 TF=13 maxTF=6 @{0 2193 2}
# contract  -> term723 Nt=4 TF=9 maxTF=3 @{0 2200 4}
# contrari  -> term1340 Nt=1 TF=1 maxTF=1 @{0 2206 1}
# contrast  -> term974 Nt=1 TF=1 maxTF=1 @{0 2207 5}
# contribut  -> term1988 Nt=2 TF=2 maxTF=1 @{0 2208 7}
# control  -> term1775 Nt=1 TF=1 maxTF=1 @{0 2210 7}
# convei  -> term2161 Nt=1 TF=1 maxTF=1 @{0 2212 5}
# convers  -> term243 Nt=1 TF=1 maxTF=1 @{0 2214 3}
# convert  -> term160 Nt=17 TF=25 maxTF=5 @{0 2215 1}
# convex  -> term1090 Nt=1 TF=1 maxTF=1 @{0 2226 5}
# cook  -> term1723 Nt=3 TF=8 maxTF=6 @{0 2228 1}
# cool  -> term528 Nt=16 TF=36 maxTF=10 @{0 2232 4}
# copper  -> term1179 Nt=3 TF=8 maxTF=4 @{0 2246 4}
# cord  -> term1748 Nt=1 TF=1 maxTF=1 @{0 2250 3}
# core  -> term987 Nt=2 TF=2 maxTF=1 @{0 2252 1}
# cork  -> term1110 Nt=1 TF=1 maxTF=1 @{0 2255 1}
# corn  -> term423 Nt=8 TF=11 maxTF=4 @{0 2256 5}
# corner  -> term1654 Nt=2 TF=2 maxTF=1 @{0 2264 2}
# correct  -> term2087 Nt=1 TF=1 maxTF=1 @{0 2266 6}
# correctli  -> term1545 Nt=1 TF=1 maxTF=1 @{0 2268 4}
# cotton  -> term1146 Nt=2 TF=3 maxTF=2 @{0 2270 0}
# count  -> term119 Nt=1 TF=1 maxTF=1 @{0 2273 1}
# counteract  -> term233 Nt=3 TF=3 maxTF=1 @{0 2273 5}
# countless  -> term831 Nt=1 TF=1 maxTF=1 @{0 2277 3}
# countri  -> term938 Nt=1 TF=1 maxTF=1 @{0 2278 5}
# coupl  -> term476 Nt=4 TF=7 maxTF=2 @{0 2279 7}
# cours  -> term1757 Nt=3 TF=3 maxTF=1 @{0 2285 0}
# coval  -> term1701 Nt=1 TF=1 maxTF=1 @{0 2288 2}
# cover  -> term468 Nt=9 TF=13 maxTF=3 @{0 2290 0}
# crack  -> term2062 Nt=1 TF=1 maxTF=1 @{0 2298 4}
# crater  -> term1449 Nt=1 TF=6 maxTF=6 @{0 2300 2}
# cream  -> term888 Nt=4 TF=4 maxTF=1 @{0 2302 3}
# creami  -> term1060 Nt=1 TF=1 maxTF=1 @{0 2307 1}
# creat  -> term257 Nt=23 TF=41 maxTF=4 @{0 2308 5}
# crete  -> term1604 Nt=1 TF=1 maxTF=1 @{0 2324 5}
# crook  -> term1468 Nt=1 TF=1 maxTF=1 @{0 2326 3}
# cross  -> term415 Nt=5 TF=20 maxTF=7 @{0 2327 7}
# crumbl  -> term1579 Nt=1 TF=1 maxTF=1 @{0 2335 2}
# crumpl  -> term342 Nt=2 TF=2 maxTF=1 @{0 2336 6}
# crush  -> term1490 Nt=2 TF=3 maxTF=2 @{0 2338 0}
# crust  -> term1450 Nt=2 TF=3 maxTF=2 @{0 2341 1}
# crystal  -> term985 Nt=7 TF=19 maxTF=9 @{0 2344 2}
# cube  -> term2044 Nt=2 TF=2 maxTF=1 @{0 2352 4}
# cultiv  -> term2106 Nt=1 TF=1 maxTF=1 @{0 2355 0}
# cup  -> term1711 Nt=3 TF=9 maxTF=4 @{0 2356 6}
# curl  -> term1580 Nt=1 TF=1 maxTF=1 @{0 2361 0}
# current  -> term650 Nt=8 TF=28 maxTF=10 @{0 2362 4}
# curv  -> term969 Nt=2 TF=4 maxTF=3 @{0 2371 6}
# curvatur  -> term2158 Nt=1 TF=2 maxTF=2 @{0 2375 0}
# cushion  -> term1779 Nt=1 TF=2 maxTF=2 @{0 2376 7}
# cut  -> term960 Nt=5 TF=7 maxTF=2 @{0 2378 6}
# cutleri  -> term764 Nt=2 TF=3 maxTF=2 @{0 2384 2}
# cycl  -> term2202 Nt=1 TF=1 maxTF=1 @{0 2387 1}
# cylind  -> term2180 Nt=1 TF=1 maxTF=1 @{0 2388 7}
# cylindr  -> term417 Nt=1 TF=1 maxTF=1 @{0 2390 5}
# dai  -> term465 Nt=8 TF=25 maxTF=16 @{0 2391 5}
# damag  -> term729 Nt=3 TF=3 maxTF=1 @{0 2401 0}
# danc  -> term1845 Nt=1 TF=1 maxTF=1 @{0 2405 0}
# danger  -> term1709 Nt=1 TF=1 maxTF=1 @{0 2406 6}
# dark  -> term844 Nt=5 TF=5 maxTF=1 @{0 2408 4}
# darker  -> term400 Nt=1 TF=1 maxTF=1 @{0 2413 6}
# date  -> term1598 Nt=1 TF=1 maxTF=1 @{0 2414 6}
# de  -> term774 Nt=2 TF=2 maxTF=1 @{0 2416 4}
# dead  -> term634 Nt=2 TF=3 maxTF=2 @{0 2419 2}
# death  -> term1089 Nt=2 TF=2 maxTF=1 @{0 2422 3}
# decid  -> term1969 Nt=1 TF=1 maxTF=1 @{0 2425 1}
# decidu  -> term1495 Nt=2 TF=4 maxTF=3 @{0 2426 7}
# decompos  -> term1005 Nt=2 TF=3 maxTF=2 @{0 2429 7}
# decomposit  -> term1013 Nt=1 TF=1 maxTF=1 @{0 2433 2}
# decreas  -> term1504 Nt=8 TF=22 maxTF=9 @{0 2434 6}
# deep  -> term2133 Nt=1 TF=1 maxTF=1 @{0 2443 2}
# deeper  -> term1643 Nt=2 TF=2 maxTF=1 @{0 2445 0}
# defici  -> term1858 Nt=1 TF=1 maxTF=1 @{0 2448 0}
# deficit  -> term1646 Nt=2 TF=2 maxTF=1 @{0 2449 6}
# defin  -> term618 Nt=5 TF=5 maxTF=1 @{0 2452 6}
# definit  -> term2230 Nt=1 TF=1 maxTF=1 @{0 2457 6}
# deform  -> term142 Nt=2 TF=12 maxTF=8 @{0 2459 4}
# degre  -> term451 Nt=7 TF=7 maxTF=1 @{0 2463 0}
# dehydr  -> term2254 Nt=1 TF=1 maxTF=1 @{0 2468 4}
# delai  -> term1621 Nt=1 TF=1 maxTF=1 @{0 2470 2}
# delv  -> term2093 Nt=1 TF=1 maxTF=1 @{0 2472 0}
# demand  -> term1660 Nt=4 TF=4 maxTF=1 @{0 2473 6}
# demonstr  -> term178 Nt=61 TF=125 maxTF=8 @{0 2477 6}
# demonstraton  -> term2203 Nt=1 TF=1 maxTF=1 @{0 2509 2}
# dens  -> term1944 Nt=1 TF=1 maxTF=1 @{0 2511 0}
# denser  -> term492 Nt=3 TF=3 maxTF=1 @{0 2512 6}
# densest  -> term1939 Nt=1 TF=1 maxTF=1 @{0 2516 6}
# densiti  -> term194 Nt=12 TF=28 maxTF=9 @{0 2518 4}
# dental  -> term1467 Nt=1 TF=3 maxTF=3 @{0 2528 4}
# dentistri  -> term1491 Nt=1 TF=1 maxTF=1 @{0 2530 2}
# deodor  -> term2214 Nt=1 TF=1 maxTF=1 @{0 2531 6}
# deoxyribonucl  -> term1225 Nt=1 TF=1 maxTF=1 @{0 2533 4}
# depart  -> term1881 Nt=1 TF=1 maxTF=1 @{0 2535 0}
# depend  -> term248 Nt=21 TF=28 maxTF=4 @{0 2536 6}
# deplet  -> term1574 Nt=1 TF=2 maxTF=2 @{0 2551 3}
# deposit  -> term1997 Nt=1 TF=3 maxTF=3 @{0 2553 0}
# depot  -> term1785 Nt=1 TF=1 maxTF=1 @{0 2555 0}
# depth  -> term2092 Nt=1 TF=2 maxTF=2 @{0 2556 6}
# der  -> term1715 Nt=1 TF=2 maxTF=2 @{0 2558 5}
# descart  -> term172 Nt=1 TF=1 maxTF=1 @{0 2560 4}
# design  -> term131 Nt=11 TF=12 maxTF=2 @{0 2561 0}
# destroi  -> term240 Nt=7 TF=7 maxTF=1 @{0 2570 3}
# detach  -> term1661 Nt=6 TF=6 maxTF=1 @{0 2576 3}
# detail  -> term1511 Nt=1 TF=1 maxTF=1 @{0 2581 3}
# detect  -> term505 Nt=8 TF=8 maxTF=1 @{0 2582 7}
# determin  -> term1220 Nt=4 TF=5 maxTF=2 @{0 2590 5}
# devast  -> term1435 Nt=1 TF=1 maxTF=1 @{0 2596 0}
# develop  -> term732 Nt=3 TF=4 maxTF=2 @{0 2597 4}
# devic  -> term85 Nt=5 TF=7 maxTF=3 @{0 2601 5}
# devil  -> term1887 Nt=1 TF=1 maxTF=1 @{0 2607 3}
# diamet  -> term439 Nt=5 TF=8 maxTF=3 @{0 2609 1}
# diaphragm  -> term1137 Nt=3 TF=3 maxTF=1 @{0 2614 4}
# didn  -> term2157 Nt=1 TF=1 maxTF=1 @{0 2618 6}
# die  -> term1074 Nt=1 TF=2 maxTF=2 @{0 2620 4}
# differ  -> term909 Nt=20 TF=29 maxTF=4 @{0 2622 1}
# difficult  -> term30 Nt=10 TF=10 maxTF=1 @{0 2635 2}
# difficulti  -> term68 Nt=1 TF=1 maxTF=1 @{0 2643 6}
# diffract  -> term2150 Nt=1 TF=1 maxTF=1 @{0 2644 0}
# diffus  -> term1630 Nt=3 TF=8 maxTF=5 @{0 2645 6}
# digest  -> term1476 Nt=1 TF=1 maxTF=1 @{0 2650 3}
# dim  -> term1312 Nt=1 TF=1 maxTF=1 @{0 2651 7}
# dimens  -> term2014 Nt=3 TF=5 maxTF=3 @{0 2653 3}
# dimension  -> term825 Nt=2 TF=7 maxTF=4 @{0 2656 5}
# diminish  -> term1417 Nt=3 TF=3 maxTF=1 @{0 2660 2}
# dinitrogen  -> term596 Nt=1 TF=1 maxTF=1 @{0 2663 2}
# dioxid  -> term562 Nt=20 TF=75 maxTF=21 @{0 2664 4}
# dioxygen  -> term587 Nt=1 TF=1 maxTF=1 @{0 2684 1}
# dip  -> term569 Nt=7 TF=12 maxTF=5 @{0 2685 3}
# diphyodont  -> term1500 Nt=1 TF=1 maxTF=1 @{0 2693 0}
# dipol  -> term1768 Nt=2 TF=4 maxTF=3 @{0 2694 4}
# dipper  -> term1668 Nt=1 TF=1 maxTF=1 @{0 2697 6}
# direct  -> term327 Nt=26 TF=65 maxTF=11 @{0 2699 4}
# directli  -> term370 Nt=5 TF=7 maxTF=3 @{0 2719 1}
# dirt  -> term1167 Nt=3 TF=6 maxTF=4 @{0 2724 5}
# disabl  -> term690 Nt=1 TF=2 maxTF=2 @{0 2729 0}
# disadvantag  -> term2023 Nt=1 TF=1 maxTF=1 @{0 2730 3}
# disappear  -> term536 Nt=4 TF=4 maxTF=1 @{0 2732 1}
# disc  -> term2177 Nt=1 TF=1 maxTF=1 @{0 2736 3}
# discharg  -> term662 Nt=1 TF=1 maxTF=1 @{0 2738 1}
# disconnect  -> term656 Nt=1 TF=1 maxTF=1 @{0 2739 3}
# discov  -> term841 Nt=2 TF=2 maxTF=1 @{0 2740 5}
# dish  -> term45 Nt=6 TF=28 maxTF=9 @{0 2743 1}
# dispers  -> term1653 Nt=3 TF=4 maxTF=2 @{0 2751 5}
# displac  -> term1385 Nt=4 TF=6 maxTF=2 @{0 2755 0}
# dispos  -> term1719 Nt=1 TF=2 maxTF=2 @{0 2759 6}
# dissect  -> term1634 Nt=1 TF=1 maxTF=1 @{0 2761 5}
# dissolv  -> term4 Nt=11 TF=27 maxTF=10 @{0 2763 3}
# distanc  -> term870 Nt=6 TF=24 maxTF=16 @{0 2774 7}
# distil  -> term275 Nt=3 TF=3 maxTF=1 @{0 2783 3}
# distinct  -> term1647 Nt=3 TF=3 maxTF=1 @{0 2787 1}
# distinguish  -> term374 Nt=3 TF=4 maxTF=2 @{0 2789 5}
# distort  -> term1752 Nt=1 TF=1 maxTF=1 @{0 2793 2}
# distribut  -> term318 Nt=5 TF=9 maxTF=4 @{0 2795 0}
# diver  -> term180 Nt=1 TF=1 maxTF=1 @{0 2800 2}
# divid  -> term67 Nt=6 TF=7 maxTF=2 @{0 2800 6}
# dna  -> term675 Nt=2 TF=21 maxTF=18 @{0 2806 3}
# document  -> term1869 Nt=1 TF=1 maxTF=1 @{0 2811 2}
# doesn  -> term363 Nt=22 TF=29 maxTF=4 @{0 2813 0}
# domin  -> term1760 Nt=2 TF=2 maxTF=1 @{0 2826 7}
# don  -> term320 Nt=14 TF=17 maxTF=2 @{0 2829 5}
# dough  -> term2097 Nt=1 TF=4 maxTF=4 @{0 2840 4}
# down  -> term246 Nt=32 TF=62 maxTF=10 @{0 2842 5}
# downspout  -> term1904 Nt=1 TF=1 maxTF=1 @{0 2863 7}
# dr  -> term1375 Nt=1 TF=1 maxTF=1 @{0 2865 5}
# draft  -> term1627 Nt=1 TF=1 maxTF=1 @{0 2867 1}
# drag  -> term1509 Nt=1 TF=1 maxTF=1 @{0 2868 7}
# drain  -> term1206 Nt=1 TF=1 maxTF=1 @{0 2870 3}
# drastic  -> term1533 Nt=2 TF=2 maxTF=1 @{0 2871 7}
# draw  -> term911 Nt=2 TF=2 maxTF=1 @{0 2874 7}
# dri  -> term1141 Nt=1 TF=1 maxTF=1 @{0 2877 5}
# drift  -> term1431 Nt=1 TF=1 maxTF=1 @{0 2879 1}
# drink  -> term2128 Nt=2 TF=2 maxTF=1 @{0 2880 5}
# drive  -> term847 Nt=1 TF=1 maxTF=1 @{0 2883 3}
# driven  -> term1827 Nt=1 TF=1 maxTF=1 @{0 2884 5}
# drop  -> term66 Nt=14 TF=33 maxTF=12 @{0 2886 3}
# dropl  -> term2143 Nt=1 TF=1 maxTF=1 @{0 2898 0}
# droplet  -> term75 Nt=9 TF=23 maxTF=5 @{0 2899 6}
# drum  -> term1126 Nt=1 TF=2 maxTF=2 @{0 2909 0}
# drumstick  -> term2168 Nt=1 TF=1 maxTF=1 @{0 2910 5}
# dry  -> term1389 Nt=4 TF=5 maxTF=2 @{0 2912 3}
# dryer  -> term2248 Nt=1 TF=4 maxTF=4 @{0 2916 6}
# du  -> term771 Nt=1 TF=1 maxTF=1 @{0 2918 7}
# duck  -> term488 Nt=1 TF=1 maxTF=1 @{0 2920 1}
# due  -> term624 Nt=22 TF=27 maxTF=3 @{0 2921 1}
# dug  -> term622 Nt=1 TF=1 maxTF=1 @{0 2935 6}
# durabl  -> term1149 Nt=2 TF=4 maxTF=2 @{0 2937 0}
# dust  -> term1122 Nt=4 TF=15 maxTF=9 @{0 2940 0}
# dwarf  -> term1288 Nt=2 TF=6 maxTF=5 @{0 2946 5}
# dynam  -> term2054 Nt=1 TF=4 maxTF=4 @{0 2949 3}
# ear  -> term482 Nt=5 TF=6 maxTF=2 @{0 2951 4}
# eardrum  -> term341 Nt=1 TF=1 maxTF=1 @{0 2957 3}
# earli  -> term855 Nt=4 TF=4 maxTF=1 @{0 2958 1}
# earliest  -> term804 Nt=1 TF=1 maxTF=1 @{0 2962 5}
# earth  -> term234 Nt=30 TF=168 maxTF=27 @{0 2963 7}
# easi  -> term506 Nt=8 TF=9 maxTF=2 @{0 2997 7}
# easier  -> term1133 Nt=6 TF=6 maxTF=1 @{0 3005 0}
# easiest  -> term1722 Nt=1 TF=1 maxTF=1 @{0 3011 0}
# easili  -> term61 Nt=15 TF=20 maxTF=2 @{0 3012 6}
# eastern  -> term802 Nt=1 TF=1 maxTF=1 @{0 3023 7}
# eat  -> term765 Nt=3 TF=8 maxTF=6 @{0 3025 1}
# ech  -> term241 Nt=1 TF=1 maxTF=1 @{0 3030 0}
# eclips  -> term444 Nt=3 TF=19 maxTF=11 @{0 3030 6}
# econom  -> term1922 Nt=1 TF=1 maxTF=1 @{0 3035 6}
# edg  -> term220 Nt=3 TF=3 maxTF=1 @{0 3037 4}
# edwin  -> term824 Nt=1 TF=1 maxTF=1 @{0 3040 6}
# effect  -> term52 Nt=12 TF=12 maxTF=1 @{0 3042 0}
# effici  -> term1949 Nt=1 TF=1 maxTF=1 @{0 3051 0}
# egg  -> term145 Nt=3 TF=26 maxTF=18 @{0 3052 6}
# eggshel  -> term92 Nt=3 TF=5 maxTF=3 @{0 3058 7}
# egypt  -> term789 Nt=1 TF=1 maxTF=1 @{0 3062 3}
# einstein  -> term1821 Nt=2 TF=2 maxTF=1 @{0 3063 5}
# elast  -> term155 Nt=1 TF=1 maxTF=1 @{0 3066 5}
# electr  -> term19 Nt=19 TF=50 maxTF=14 @{0 3067 1}
# electromagnet  -> term647 Nt=4 TF=18 maxTF=9 @{0 3082 6}
# electron  -> term1416 Nt=15 TF=92 maxTF=22 @{0 3090 0}
# element  -> term2224 Nt=1 TF=1 maxTF=1 @{0 3108 5}
# elev  -> term2140 Nt=1 TF=2 maxTF=2 @{0 3110 3}
# ellipt  -> term453 Nt=4 TF=8 maxTF=4 @{0 3112 2}
# elong  -> term1457 Nt=1 TF=1 maxTF=1 @{0 3117 0}
# emerg  -> term1209 Nt=3 TF=3 maxTF=1 @{0 3118 4}
# emit  -> term1432 Nt=3 TF=4 maxTF=2 @{0 3122 0}
# empir  -> term768 Nt=1 TF=2 maxTF=2 @{0 3126 1}
# empti  -> term929 Nt=5 TF=5 maxTF=1 @{0 3127 4}
# encapsul  -> term1226 Nt=2 TF=2 maxTF=1 @{0 3133 0}
# enclos  -> term1568 Nt=2 TF=2 maxTF=1 @{0 3136 0}
# encount  -> term2055 Nt=2 TF=2 maxTF=1 @{0 3137 6}
# end  -> term78 Nt=37 TF=84 maxTF=12 @{0 3140 6}
# enemi  -> term1155 Nt=1 TF=1 maxTF=1 @{0 3165 1}
# energi  -> term137 Nt=27 TF=176 maxTF=22 @{0 3166 5}
# energia  -> term1848 Nt=1 TF=1 maxTF=1 @{0 3200 4}
# energysinc  -> term1651 Nt=2 TF=2 maxTF=1 @{0 3202 2}
# energythi  -> term1736 Nt=1 TF=1 maxTF=1 @{0 3204 2}
# engin  -> term1227 Nt=2 TF=3 maxTF=2 @{0 3206 0}
# englishman  -> term1175 Nt=2 TF=2 maxTF=1 @{0 3209 1}
# enorm  -> term1082 Nt=1 TF=1 maxTF=1 @{0 3210 7}
# ensur  -> term2017 Nt=1 TF=1 maxTF=1 @{0 3212 3}
# enter  -> term737 Nt=5 TF=6 maxTF=2 @{0 3214 1}
# entir  -> term443 Nt=14 TF=17 maxTF=2 @{0 3220 0}
# environ  -> term1629 Nt=4 TF=5 maxTF=2 @{0 3230 3}
# equal  -> term408 Nt=14 TF=21 maxTF=2 @{0 3234 6}
# equat  -> term1016 Nt=3 TF=3 maxTF=1 @{0 3246 3}
# equilibrium  -> term1109 Nt=5 TF=7 maxTF=3 @{0 3249 5}
# equilibriumat  -> term2058 Nt=1 TF=1 maxTF=1 @{0 3254 7}
# equinox  -> term2234 Nt=1 TF=2 maxTF=2 @{0 3256 5}
# equip  -> term1644 Nt=1 TF=1 maxTF=1 @{0 3258 4}
# equival  -> term313 Nt=1 TF=1 maxTF=1 @{0 3260 2}
# erik  -> term2208 Nt=1 TF=1 maxTF=1 @{0 3261 0}
# eros  -> term604 Nt=3 TF=3 maxTF=1 @{0 3262 6}
# error  -> term830 Nt=3 TF=6 maxTF=3 @{0 3267 0}
# escap  -> term573 Nt=11 TF=14 maxTF=3 @{0 3270 5}
# especi  -> term534 Nt=3 TF=3 maxTF=1 @{0 3279 4}
# estim  -> term1892 Nt=1 TF=4 maxTF=4 @{0 3283 0}
# ethan  -> term1712 Nt=1 TF=1 maxTF=1 @{0 3285 1}
# ethanol  -> term1114 Nt=4 TF=43 maxTF=16 @{0 3286 7}
# europ  -> term770 Nt=1 TF=1 maxTF=1 @{0 3295 6}
# europadiamet  -> term1273 Nt=1 TF=1 maxTF=1 @{0 3297 0}
# evapor  -> term561 Nt=19 TF=67 maxTF=15 @{0 3298 4}
# evaporationth  -> term2074 Nt=1 TF=1 maxTF=1 @{0 3316 2}
# evenli  -> term1726 Nt=2 TF=2 maxTF=1 @{0 3318 0}
# event  -> term806 Nt=3 TF=3 maxTF=1 @{0 3320 4}
# eventu  -> term235 Nt=5 TF=5 maxTF=1 @{0 3324 0}
# everydai  -> term1727 Nt=1 TF=1 maxTF=1 @{0 3329 0}
# evolutionari  -> term511 Nt=3 TF=3 maxTF=1 @{0 3330 6}
# exact  -> term1180 Nt=2 TF=2 maxTF=1 @{0 3334 2}
# exactli  -> term464 Nt=13 TF=14 maxTF=2 @{0 3336 0}
# exagger  -> term516 Nt=1 TF=1 maxTF=1 @{0 3345 3}
# examin  -> term720 Nt=1 TF=1 maxTF=1 @{0 3346 3}
# exampl  -> term2 Nt=41 TF=68 maxTF=5 @{0 3347 5}
# excel  -> term1915 Nt=1 TF=1 maxTF=1 @{0 3370 4}
# excess  -> term1414 Nt=7 TF=8 maxTF=2 @{0 3372 2}
# excit  -> term2226 Nt=1 TF=9 maxTF=9 @{0 3379 1}
# exercis  -> term921 Nt=2 TF=3 maxTF=2 @{0 3381 7}
# exert  -> term814 Nt=4 TF=7 maxTF=2 @{0 3385 0}
# exist  -> term36 Nt=12 TF=12 maxTF=1 @{0 3390 3}
# exotherm  -> term1023 Nt=6 TF=9 maxTF=2 @{0 3398 5}
# expand  -> term854 Nt=5 TF=10 maxTF=6 @{0 3405 0}
# expans  -> term852 Nt=2 TF=6 maxTF=5 @{0 3411 5}
# expect  -> term351 Nt=2 TF=2 maxTF=1 @{0 3414 7}
# expel  -> term2205 Nt=1 TF=1 maxTF=1 @{0 3417 3}
# experi  -> term197 Nt=44 TF=94 maxTF=4 @{0 3419 1}
# experimentthi  -> term2190 Nt=2 TF=2 maxTF=1 @{0 3446 1}
# experimenty  -> term212 Nt=42 TF=42 maxTF=1 @{0 3448 5}
# expir  -> term910 Nt=1 TF=1 maxTF=1 @{0 3468 5}
# expiratori  -> term907 Nt=1 TF=2 maxTF=2 @{0 3469 7}
# explain  -> term950 Nt=5 TF=7 maxTF=3 @{0 3471 2}
# explan  -> term1557 Nt=5 TF=13 maxTF=7 @{0 3477 4}
# explanationand  -> term2090 Nt=1 TF=1 maxTF=1 @{0 3483 4}
# explanationwat  -> term2057 Nt=1 TF=1 maxTF=1 @{0 3485 2}
# explos  -> term1437 Nt=2 TF=4 maxTF=2 @{0 3487 0}
# expos  -> term1240 Nt=5 TF=5 maxTF=1 @{0 3490 0}
# extent  -> term1112 Nt=7 TF=7 maxTF=1 @{0 3494 4}
# extinct  -> term1427 Nt=1 TF=1 maxTF=1 @{0 3500 4}
# extinguish  -> term1515 Nt=4 TF=7 maxTF=4 @{0 3502 0}
# extra  -> term919 Nt=7 TF=8 maxTF=2 @{0 3506 3}
# extract  -> term1223 Nt=1 TF=2 maxTF=2 @{0 3513 2}
# extrem  -> term992 Nt=5 TF=5 maxTF=1 @{0 3514 7}
# extuingish  -> term1518 Nt=1 TF=1 maxTF=1 @{0 3520 3}
# ey  -> term673 Nt=10 TF=14 maxTF=5 @{0 3521 7}
# eyesight  -> term730 Nt=1 TF=1 maxTF=1 @{0 3530 5}
# fabric  -> term1356 Nt=1 TF=1 maxTF=1 @{0 3531 7}
# face  -> term1411 Nt=6 TF=6 maxTF=1 @{0 3533 3}
# factor  -> term486 Nt=5 TF=8 maxTF=2 @{0 3539 1}
# factori  -> term2102 Nt=1 TF=1 maxTF=1 @{0 3545 2}
# fairli  -> term661 Nt=2 TF=2 maxTF=1 @{0 3547 0}
# fake  -> term2039 Nt=1 TF=5 maxTF=5 @{0 3549 6}
# fall  -> term356 Nt=8 TF=11 maxTF=2 @{0 3552 0}
# familiar  -> term1677 Nt=1 TF=1 maxTF=1 @{0 3560 1}
# famous  -> term1455 Nt=1 TF=1 maxTF=1 @{0 3561 7}
# fantast  -> term1305 Nt=1 TF=1 maxTF=1 @{0 3563 3}
# far  -> term459 Nt=15 TF=16 maxTF=2 @{0 3564 7}
# faradai  -> term1187 Nt=2 TF=2 maxTF=1 @{0 3575 4}
# farm  -> term424 Nt=1 TF=1 maxTF=1 @{0 3577 2}
# farther  -> term821 Nt=2 TF=3 maxTF=2 @{0 3578 2}
# fascin  -> term517 Nt=2 TF=2 maxTF=1 @{0 3580 7}
# fast  -> term478 Nt=14 TF=20 maxTF=2 @{0 3583 5}
# faster  -> term99 Nt=19 TF=27 maxTF=4 @{0 3594 3}
# fastest  -> term633 Nt=3 TF=4 maxTF=2 @{0 3608 3}
# fat  -> term71 Nt=3 TF=13 maxTF=10 @{0 3612 4}
# fatal  -> term1734 Nt=1 TF=1 maxTF=1 @{0 3616 6}
# favor  -> term1471 Nt=1 TF=1 maxTF=1 @{0 3618 4}
# feel  -> term349 Nt=8 TF=9 maxTF=2 @{0 3620 0}
# feet  -> term346 Nt=3 TF=5 maxTF=2 @{0 3626 3}
# feldspar  -> term2003 Nt=1 TF=2 maxTF=2 @{0 3630 1}
# felt  -> term1798 Nt=2 TF=2 maxTF=1 @{0 3632 0}
# ferment  -> term1073 Nt=1 TF=2 maxTF=2 @{0 3635 0}
# ferromagnet  -> term657 Nt=1 TF=1 maxTF=1 @{0 3636 5}
# field  -> term989 Nt=4 TF=18 maxTF=8 @{0 3637 7}
# figur  -> term1351 Nt=2 TF=2 maxTF=1 @{0 3642 7}
# file  -> term762 Nt=1 TF=1 maxTF=1 @{0 3645 3}
# fill  -> term185 Nt=13 TF=22 maxTF=3 @{0 3646 5}
# film  -> term878 Nt=3 TF=9 maxTF=4 @{0 3658 6}
# filter  -> term1212 Nt=2 TF=3 maxTF=2 @{0 3663 4}
# final  -> term1200 Nt=3 TF=4 maxTF=2 @{0 3666 5}
# find  -> term1282 Nt=7 TF=11 maxTF=2 @{0 3670 2}
# fine  -> term2171 Nt=1 TF=1 maxTF=1 @{0 3678 0}
# finger  -> term1355 Nt=6 TF=25 maxTF=9 @{0 3679 6}
# fire  -> term552 Nt=11 TF=39 maxTF=16 @{0 3687 7}
# fireproof  -> term894 Nt=1 TF=1 maxTF=1 @{0 3699 5}
# firework  -> term2229 Nt=1 TF=1 maxTF=1 @{0 3700 7}
# first  -> term127 Nt=25 TF=33 maxTF=3 @{0 3702 5}
# fish  -> term1633 Nt=1 TF=1 maxTF=1 @{0 3718 5}
# fit  -> term141 Nt=7 TF=7 maxTF=1 @{0 3720 3}
# fix  -> term1516 Nt=2 TF=2 maxTF=1 @{0 3726 7}
# flame  -> term553 Nt=12 TF=38 maxTF=11 @{0 3729 5}
# flammabl  -> term941 Nt=4 TF=4 maxTF=1 @{0 3741 1}
# flash  -> term2119 Nt=1 TF=5 maxTF=5 @{0 3745 5}
# flashi  -> term1190 Nt=1 TF=1 maxTF=1 @{0 3747 7}
# flat  -> term1489 Nt=3 TF=3 maxTF=1 @{0 3749 3}
# flavor  -> term1066 Nt=1 TF=2 maxTF=2 @{0 3753 3}
# fli  -> term579 Nt=3 TF=4 maxTF=2 @{0 3755 0}
# flip  -> term1506 Nt=1 TF=1 maxTF=1 @{0 3758 1}
# float  -> term184 Nt=9 TF=17 maxTF=4 @{0 3759 5}
# floor  -> term146 Nt=4 TF=5 maxTF=2 @{0 3767 7}
# flour  -> term1383 Nt=3 TF=11 maxTF=9 @{0 3771 0}
# flow  -> term230 Nt=8 TF=10 maxTF=2 @{0 3775 4}
# flower  -> term1401 Nt=1 TF=7 maxTF=7 @{0 3783 0}
# fluffi  -> term2098 Nt=2 TF=2 maxTF=1 @{0 3785 2}
# fluid  -> term1384 Nt=3 TF=10 maxTF=7 @{0 3787 6}
# flush  -> term1900 Nt=1 TF=1 maxTF=1 @{0 3791 7}
# fly  -> term334 Nt=3 TF=4 maxTF=2 @{0 3793 5}
# foam  -> term1708 Nt=3 TF=7 maxTF=3 @{0 3797 4}
# fold  -> term378 Nt=1 TF=1 maxTF=1 @{0 3802 0}
# follicl  -> term735 Nt=1 TF=1 maxTF=1 @{0 3803 0}
# follow  -> term110 Nt=53 TF=59 maxTF=2 @{0 3804 2}
# food  -> term16 Nt=11 TF=20 maxTF=6 @{0 3827 4}
# footbal  -> term1266 Nt=1 TF=1 maxTF=1 @{0 3837 1}
# footprint  -> term366 Nt=1 TF=1 maxTF=1 @{0 3838 5}
# forc  -> term69 Nt=38 TF=85 maxTF=8 @{0 3839 5}
# forest  -> term672 Nt=2 TF=4 maxTF=3 @{0 3864 2}
# fork  -> term797 Nt=1 TF=8 maxTF=8 @{0 3867 2}
# form  -> term43 Nt=49 TF=139 maxTF=13 @{0 3869 3}
# format  -> term11 Nt=3 TF=3 maxTF=1 @{0 3900 5}
# forth  -> term1361 Nt=2 TF=2 maxTF=1 @{0 3903 3}
# forward  -> term968 Nt=5 TF=6 maxTF=2 @{0 3906 1}
# fossil  -> term1691 Nt=1 TF=1 maxTF=1 @{0 3911 6}
# found  -> term979 Nt=3 TF=4 maxTF=2 @{0 3913 4}
# fraction  -> term1092 Nt=1 TF=1 maxTF=1 @{0 3917 7}
# fragil  -> term116 Nt=2 TF=2 maxTF=1 @{0 3919 3}
# free  -> term1158 Nt=5 TF=5 maxTF=1 @{0 3921 1}
# freedom  -> term578 Nt=1 TF=1 maxTF=1 @{0 3926 1}
# freeli  -> term63 Nt=3 TF=3 maxTF=1 @{0 3927 3}
# freez  -> term1107 Nt=5 TF=6 maxTF=2 @{0 3930 5}
# french  -> term202 Nt=2 TF=2 maxTF=1 @{0 3936 2}
# frenzi  -> term2094 Nt=1 TF=1 maxTF=1 @{0 3938 0}
# frequenc  -> term1564 Nt=2 TF=2 maxTF=1 @{0 3939 6}
# frequent  -> term494 Nt=3 TF=3 maxTF=1 @{0 3941 4}
# fresh  -> term1642 Nt=2 TF=4 maxTF=3 @{0 3945 0}
# freshen  -> term2220 Nt=1 TF=3 maxTF=3 @{0 3948 2}
# friction  -> term238 Nt=4 TF=5 maxTF=2 @{0 3950 2}
# fridg  -> term1055 Nt=1 TF=1 maxTF=1 @{0 3955 1}
# friend  -> term1342 Nt=3 TF=3 maxTF=1 @{0 3956 5}
# front  -> term455 Nt=6 TF=8 maxTF=3 @{0 3959 7}
# frozen  -> term1756 Nt=3 TF=3 maxTF=1 @{0 3965 5}
# fruit  -> term593 Nt=3 TF=3 maxTF=1 @{0 3969 3}
# fry  -> term1840 Nt=1 TF=5 maxTF=5 @{0 3972 5}
# ft  -> term1231 Nt=5 TF=16 maxTF=9 @{0 3974 7}
# fuel  -> term548 Nt=9 TF=38 maxTF=12 @{0 3981 4}
# fulfil  -> term718 Nt=1 TF=1 maxTF=1 @{0 3993 3}
# full  -> term1160 Nt=6 TF=12 maxTF=4 @{0 3994 5}
# fulli  -> term518 Nt=3 TF=3 maxTF=1 @{0 4001 3}
# fun  -> term1552 Nt=1 TF=1 maxTF=1 @{0 4005 3}
# function  -> term113 Nt=6 TF=9 maxTF=2 @{0 4006 7}
# fungi  -> term2095 Nt=1 TF=1 maxTF=1 @{0 4014 0}
# fungu  -> term2096 Nt=1 TF=1 maxTF=1 @{0 4015 6}
# funnel  -> term1729 Nt=1 TF=2 maxTF=2 @{0 4017 4}
# fusion  -> term1097 Nt=1 TF=1 maxTF=1 @{0 4019 3}
# futur  -> term1452 Nt=1 TF=1 maxTF=1 @{0 4020 7}
# ga  -> term890 Nt=24 TF=71 maxTF=10 @{0 4022 3}
# gain  -> term2181 Nt=1 TF=1 maxTF=1 @{0 4041 6}
# galaxi  -> term837 Nt=2 TF=20 maxTF=19 @{0 4043 4}
# ganymedediamet  -> term1300 Nt=1 TF=1 maxTF=1 @{0 4048 4}
# gap  -> term1582 Nt=3 TF=10 maxTF=5 @{0 4050 0}
# gase  -> term895 Nt=4 TF=5 maxTF=2 @{0 4054 1}
# gaseou  -> term555 Nt=22 TF=34 maxTF=3 @{0 4059 0}
# gasifi  -> term1910 Nt=1 TF=1 maxTF=1 @{0 4074 0}
# gather  -> term1512 Nt=4 TF=5 maxTF=2 @{0 4075 6}
# gave  -> term1986 Nt=1 TF=1 maxTF=1 @{0 4079 7}
# gelatin  -> term2249 Nt=1 TF=1 maxTF=1 @{0 4081 5}
# gene  -> term1204 Nt=1 TF=2 maxTF=2 @{0 4083 3}
# gener  -> term94 Nt=6 TF=6 maxTF=1 @{0 4085 0}
# gentli  -> term1619 Nt=1 TF=1 maxTF=1 @{0 4090 2}
# geod  -> term2002 Nt=1 TF=8 maxTF=8 @{0 4092 0}
# geograph  -> term1964 Nt=1 TF=1 maxTF=1 @{0 4094 5}
# geometr  -> term1164 Nt=2 TF=2 maxTF=1 @{0 4096 3}
# germin  -> term2067 Nt=1 TF=1 maxTF=1 @{0 4099 1}
# ghost  -> term1415 Nt=1 TF=7 maxTF=7 @{0 4100 7}
# giant  -> term822 Nt=3 TF=3 maxTF=1 @{0 4103 1}
# give  -> term375 Nt=10 TF=16 maxTF=4 @{0 4107 1}
# given  -> term2042 Nt=2 TF=2 maxTF=1 @{0 4116 7}
# glacier  -> term1901 Nt=2 TF=2 maxTF=1 @{0 4119 1}
# glass  -> term1096 Nt=12 TF=54 maxTF=27 @{0 4121 5}
# glide  -> term1993 Nt=1 TF=1 maxTF=1 @{0 4136 5}
# globe  -> term1765 Nt=2 TF=3 maxTF=2 @{0 4138 3}
# glow  -> term1439 Nt=1 TF=1 maxTF=1 @{0 4141 6}
# glucos  -> term1743 Nt=2 TF=6 maxTF=3 @{0 4143 2}
# glycerin  -> term1159 Nt=2 TF=6 maxTF=3 @{0 4146 6}
# go  -> term826 Nt=3 TF=3 maxTF=1 @{0 4150 0}
# goe  -> term566 Nt=8 TF=10 maxTF=2 @{0 4153 6}
# goo  -> term1387 Nt=1 TF=1 maxTF=1 @{0 4161 2}
# good  -> term433 Nt=1 TF=1 maxTF=1 @{0 4162 6}
# googl  -> term1917 Nt=1 TF=1 maxTF=1 @{0 4163 6}
# goos  -> term708 Nt=1 TF=1 maxTF=1 @{0 4165 4}
# gottlob  -> term1834 Nt=1 TF=1 maxTF=1 @{0 4166 6}
# grab  -> term1883 Nt=1 TF=1 maxTF=1 @{0 4168 4}
# graduat  -> term1761 Nt=1 TF=1 maxTF=1 @{0 4170 2}
# grain  -> term436 Nt=6 TF=25 maxTF=11 @{0 4172 0}
# graini  -> term430 Nt=1 TF=1 maxTF=1 @{0 4180 3}
# granit  -> term2007 Nt=1 TF=2 maxTF=2 @{0 4181 3}
# grant  -> term750 Nt=1 TF=1 maxTF=1 @{0 4183 2}
# granul  -> term1742 Nt=1 TF=1 maxTF=1 @{0 4184 4}
# grate  -> term2145 Nt=1 TF=1 maxTF=1 @{0 4186 2}
# gravel  -> term617 Nt=1 TF=3 maxTF=3 @{0 4188 0}
# gravit  -> term269 Nt=9 TF=16 maxTF=6 @{0 4189 4}
# gravitation  -> term845 Nt=1 TF=1 maxTF=1 @{0 4198 5}
# ...
# suck  -> term1398 Nt=7 TF=14 maxTF=6 @{0 8730 1}
# sucros  -> term1003 Nt=1 TF=2 maxTF=2 @{0 8737 0}
# suction  -> term1408 Nt=5 TF=11 maxTF=3 @{0 8738 5}
# suffici  -> term567 Nt=8 TF=13 maxTF=4 @{0 8744 1}
# sugar  -> term1029 Nt=11 TF=21 maxTF=5 @{0 8752 6}
# suggest  -> term1966 Nt=2 TF=2 maxTF=1 @{0 8762 2}
# suitabl  -> term1502 Nt=1 TF=1 maxTF=1 @{0 8764 2}
# sulphat  -> term2016 Nt=1 TF=1 maxTF=1 @{0 8765 6}
# sum  -> term1790 Nt=1 TF=1 maxTF=1 @{0 8767 4}
# summar  -> term2175 Nt=1 TF=1 maxTF=1 @{0 8769 2}
# summari  -> term1481 Nt=1 TF=1 maxTF=1 @{0 8771 0}
# summer  -> term1970 Nt=2 TF=5 maxTF=4 @{0 8772 4}
# sun  -> term456 Nt=20 TF=90 maxTF=19 @{0 8775 7}
# sunlight  -> term457 Nt=3 TF=3 maxTF=1 @{0 8797 5}
# super  -> term1777 Nt=2 TF=2 maxTF=1 @{0 8801 3}
# support  -> term380 Nt=3 TF=9 maxTF=5 @{0 8803 7}
# suppos  -> term2085 Nt=1 TF=1 maxTF=1 @{0 8808 1}
# sure  -> term1575 Nt=4 TF=4 maxTF=1 @{0 8809 7}
# surfac  -> term219 Nt=45 TF=126 maxTF=26 @{0 8814 5}
# surround  -> term54 Nt=21 TF=30 maxTF=3 @{0 8844 6}
# surroungin  -> term1530 Nt=1 TF=1 maxTF=1 @{0 8859 1}
# surviv  -> term716 Nt=3 TF=3 maxTF=1 @{0 8860 5}
# suscept  -> term1778 Nt=1 TF=1 maxTF=1 @{0 8864 5}
# suspens  -> term1932 Nt=1 TF=1 maxTF=1 @{0 8866 3}
# sustain  -> term1567 Nt=1 TF=1 maxTF=1 @{0 8868 1}
# sweden  -> term943 Nt=2 TF=2 maxTF=1 @{0 8869 5}
# swell  -> term1624 Nt=3 TF=7 maxTF=3 @{0 8872 3}
# swing  -> term1381 Nt=2 TF=2 maxTF=1 @{0 8877 1}
# switch  -> term1733 Nt=1 TF=1 maxTF=1 @{0 8880 1}
# swollen  -> term2251 Nt=1 TF=1 maxTF=1 @{0 8881 7}
# symbol  -> term2222 Nt=1 TF=1 maxTF=1 @{0 8883 5}
# syrup  -> term1793 Nt=1 TF=1 maxTF=1 @{0 8885 3}
# system  -> term1083 Nt=5 TF=15 maxTF=9 @{0 8887 1}
# systemif  -> term1303 Nt=1 TF=1 maxTF=1 @{0 8893 3}
# tabl  -> term777 Nt=4 TF=4 maxTF=1 @{0 8894 7}
# tablespoon  -> term1036 Nt=2 TF=2 maxTF=1 @{0 8899 5}
# tail  -> term2122 Nt=1 TF=6 maxTF=6 @{0 8902 5}
# take  -> term284 Nt=39 TF=53 maxTF=5 @{0 8905 0}
# taken  -> term1293 Nt=2 TF=3 maxTF=2 @{0 8925 0}
# talk  -> term226 Nt=5 TF=5 maxTF=1 @{0 8927 7}
# tall  -> term326 Nt=1 TF=1 maxTF=1 @{0 8932 7}
# taller  -> term1563 Nt=1 TF=1 maxTF=1 @{0 8933 5}
# tallest  -> term384 Nt=2 TF=2 maxTF=1 @{0 8935 1}
# tame  -> term2113 Nt=1 TF=1 maxTF=1 @{0 8937 5}
# tap  -> term2066 Nt=2 TF=5 maxTF=4 @{0 8939 3}
# tape  -> term2178 Nt=1 TF=1 maxTF=1 @{0 8942 4}
# tartar  -> term879 Nt=4 TF=4 maxTF=1 @{0 8944 2}
# task  -> term2197 Nt=1 TF=1 maxTF=1 @{0 8949 0}
# tast  -> term1056 Nt=2 TF=2 maxTF=1 @{0 8950 6}
# tea  -> term948 Nt=1 TF=11 maxTF=11 @{0 8953 6}
# tear  -> term665 Nt=5 TF=10 maxTF=4 @{0 8956 2}
# technic  -> term2154 Nt=1 TF=1 maxTF=1 @{0 8962 7}
# technolog  -> term126 Nt=12 TF=14 maxTF=2 @{0 8964 5}
# teeth  -> term783 Nt=2 TF=27 maxTF=26 @{0 8975 5}
# telephon  -> term1750 Nt=1 TF=4 maxTF=4 @{0 8981 4}
# telescop  -> term828 Nt=2 TF=2 maxTF=1 @{0 8983 5}
# tell  -> term1443 Nt=1 TF=1 maxTF=1 @{0 8986 1}
# temperatur  -> term106 Nt=33 TF=99 maxTF=12 @{0 8987 5}
# ten  -> term1456 Nt=1 TF=1 maxTF=1 @{0 9012 5}
# tend  -> term1348 Nt=5 TF=6 maxTF=2 @{0 9014 1}
# tendon  -> term711 Nt=1 TF=7 maxTF=7 @{0 9020 0}
# tenni  -> term1142 Nt=1 TF=1 maxTF=1 @{0 9022 0}
# tension  -> term223 Nt=9 TF=9 maxTF=1 @{0 9023 4}
# term  -> term152 Nt=3 TF=3 maxTF=1 @{0 9030 6}
# termin  -> term654 Nt=4 TF=6 maxTF=2 @{0 9034 2}
# terrain  -> term1921 Nt=1 TF=1 maxTF=1 @{0 9038 6}
# terresti  -> term1326 Nt=1 TF=1 maxTF=1 @{0 9040 4}
# terrestri  -> term1906 Nt=1 TF=1 maxTF=1 @{0 9042 0}
# test  -> term140 Nt=54 TF=58 maxTF=3 @{0 9043 6}
# thank  -> term649 Nt=8 TF=8 maxTF=1 @{0 9066 6}
# theoret  -> term1992 Nt=2 TF=2 maxTF=1 @{0 9073 4}
# theori  -> term2163 Nt=1 TF=1 maxTF=1 @{0 9076 0}
# thermal  -> term96 Nt=13 TF=19 maxTF=2 @{0 9077 6}
# thermodynam  -> term163 Nt=1 TF=1 maxTF=1 @{0 9087 0}
# thermomet  -> term1759 Nt=1 TF=4 maxTF=4 @{0 9087 4}
# thick  -> term413 Nt=4 TF=4 maxTF=1 @{0 9089 5}
# thicken  -> term1046 Nt=1 TF=2 maxTF=2 @{0 9094 7}
# thicker  -> term396 Nt=3 TF=3 maxTF=1 @{0 9096 4}
# thin  -> term1782 Nt=4 TF=6 maxTF=3 @{0 9100 0}
# think  -> term292 Nt=12 TF=13 maxTF=2 @{0 9105 0}
# thinner  -> term343 Nt=3 TF=4 maxTF=2 @{0 9115 1}
# third  -> term809 Nt=2 TF=2 maxTF=1 @{0 9119 0}
# thought  -> term865 Nt=2 TF=2 maxTF=1 @{0 9121 2}
# thousand  -> term767 Nt=3 TF=3 maxTF=1 @{0 9124 0}
# thread  -> term1764 Nt=1 TF=1 maxTF=1 @{0 9127 6}
# threaten  -> term736 Nt=1 TF=1 maxTF=1 @{0 9129 4}
# thrive  -> term1037 Nt=1 TF=1 maxTF=1 @{0 9130 6}
# throw  -> term1048 Nt=1 TF=1 maxTF=1 @{0 9132 2}
# thrown  -> term10 Nt=3 TF=3 maxTF=1 @{0 9133 6}
# thumb  -> term590 Nt=2 TF=3 maxTF=2 @{0 9136 6}
# thundercloud  -> term1878 Nt=2 TF=2 maxTF=1 @{0 9139 7}
# thunderstorm  -> term1867 Nt=1 TF=1 maxTF=1 @{0 9142 5}
# ti  -> term1103 Nt=1 TF=1 maxTF=1 @{0 9144 3}
# tidal  -> term925 Nt=1 TF=2 maxTF=2 @{0 9145 7}
# tie  -> term2124 Nt=1 TF=1 maxTF=1 @{0 9147 2}
# tight  -> term1565 Nt=1 TF=1 maxTF=1 @{0 9149 0}
# tightli  -> term1526 Nt=4 TF=4 maxTF=1 @{0 9150 4}
# tilt  -> term743 Nt=6 TF=13 maxTF=8 @{0 9155 2}
# time  -> term128 Nt=49 TF=90 maxTF=9 @{0 9162 5}
# tini  -> term192 Nt=3 TF=3 maxTF=1 @{0 9188 4}
# tip  -> term484 Nt=5 TF=7 maxTF=2 @{0 9191 4}
# tipsa  -> term2084 Nt=1 TF=1 maxTF=1 @{0 9197 4}
# tire  -> term803 Nt=1 TF=1 maxTF=1 @{0 9199 2}
# tissu  -> term300 Nt=1 TF=4 maxTF=4 @{0 9200 4}
# titandiamet  -> term1277 Nt=1 TF=1 maxTF=1 @{0 9201 5}
# todai  -> term791 Nt=3 TF=3 maxTF=1 @{0 9203 1}
# toi  -> term958 Nt=1 TF=5 maxTF=5 @{0 9206 1}
# toilet  -> term425 Nt=2 TF=8 maxTF=6 @{0 9207 7}
# tone  -> term2169 Nt=1 TF=1 maxTF=1 @{0 9210 7}
# tonn  -> term1902 Nt=1 TF=1 maxTF=1 @{0 9212 5}
# took  -> term1257 Nt=2 TF=2 maxTF=1 @{0 9214 3}
# tool  -> term773 Nt=2 TF=3 maxTF=2 @{0 9217 3}
# tooth  -> term1499 Nt=1 TF=2 maxTF=2 @{0 9220 2}
# top  -> term231 Nt=15 TF=24 maxTF=4 @{0 9221 7}
# toppl  -> term365 Nt=2 TF=2 maxTF=1 @{0 9234 4}
# torn  -> term419 Nt=2 TF=2 maxTF=1 @{0 9236 6}
# tornado  -> term1877 Nt=1 TF=5 maxTF=5 @{0 9238 6}
# total  -> term446 Nt=5 TF=6 maxTF=2 @{0 9241 0}
# touch  -> term1380 Nt=6 TF=11 maxTF=3 @{0 9246 3}
# tough  -> term1473 Nt=1 TF=1 maxTF=1 @{0 9252 0}
# towel  -> term1349 Nt=3 TF=12 maxTF=7 @{0 9253 4}
# tower  -> term362 Nt=2 TF=12 maxTF=9 @{0 9258 3}
# toxic  -> term2193 Nt=1 TF=1 maxTF=1 @{0 9262 1}
# trace  -> term1008 Nt=1 TF=1 maxTF=1 @{0 9263 7}
# track  -> term1862 Nt=1 TF=1 maxTF=1 @{0 9265 3}
# tradition  -> term1124 Nt=1 TF=1 maxTF=1 @{0 9267 1}
# traffic  -> term2167 Nt=1 TF=1 maxTF=1 @{0 9268 5}
# tragic  -> term1739 Nt=1 TF=1 maxTF=1 @{0 9270 3}
# trait  -> term1207 Nt=1 TF=1 maxTF=1 @{0 9272 1}
# transfer  -> term922 Nt=5 TF=13 maxTF=3 @{0 9273 5}
# transform  -> term239 Nt=6 TF=8 maxTF=2 @{0 9279 5}
# transit  -> term2151 Nt=1 TF=1 maxTF=1 @{0 9285 3}
# translat  -> term1817 Nt=1 TF=1 maxTF=1 @{0 9287 1}
# translation  -> term1811 Nt=1 TF=1 maxTF=1 @{0 9288 7}
# transpar  -> term1532 Nt=5 TF=5 maxTF=1 @{0 9290 5}
# transport  -> term1400 Nt=7 TF=11 maxTF=5 @{0 9296 1}
# trap  -> term1570 Nt=4 TF=5 maxTF=2 @{0 9303 1}
# trash  -> term964 Nt=2 TF=5 maxTF=4 @{0 9308 0}
# travel  -> term533 Nt=5 TF=12 maxTF=4 @{0 9311 1}
# treat  -> term1721 Nt=1 TF=1 maxTF=1 @{0 9318 0}
# tree  -> term1960 Nt=1 TF=5 maxTF=5 @{0 9319 6}
# treetop  -> term1875 Nt=1 TF=1 maxTF=1 @{0 9322 0}
# tri  -> term2244 Nt=1 TF=1 maxTF=1 @{0 9323 6}
# triangl  -> term1235 Nt=4 TF=8 maxTF=3 @{0 9325 4}
# tricki  -> term387 Nt=1 TF=1 maxTF=1 @{0 9330 0}
# trio  -> term1776 Nt=1 TF=1 maxTF=1 @{0 9331 0}
# tritondiamet  -> term1314 Nt=1 TF=1 maxTF=1 @{0 9332 6}
# trough  -> term1353 Nt=1 TF=1 maxTF=1 @{0 9334 2}
# true  -> term840 Nt=7 TF=9 maxTF=2 @{0 9335 6}
# trunk  -> term1602 Nt=2 TF=3 maxTF=2 @{0 9342 2}
# truss  -> term1248 Nt=2 TF=7 maxTF=4 @{0 9345 3}
# truth  -> term1692 Nt=1 TF=1 maxTF=1 @{0 9349 0}
# try  -> term117 Nt=55 TF=69 maxTF=4 @{0 9350 6}
# tube  -> term936 Nt=3 TF=7 maxTF=3 @{0 9375 2}
# tune  -> term1555 Nt=1 TF=1 maxTF=1 @{0 9379 0}
# turbul  -> term1519 Nt=1 TF=1 maxTF=1 @{0 9380 4}
# turn  -> term207 Nt=54 TF=69 maxTF=3 @{0 9382 0}
# twice  -> term438 Nt=3 TF=4 maxTF=2 @{0 9406 3}
# twist  -> term1222 Nt=1 TF=1 maxTF=1 @{0 9409 4}
# tyler  -> term1682 Nt=1 TF=1 maxTF=1 @{0 9411 0}
# type  -> term406 Nt=19 TF=24 maxTF=3 @{0 9412 6}
# ultraviolet  -> term1087 Nt=1 TF=1 maxTF=1 @{0 9426 1}
# uncertain  -> term1595 Nt=1 TF=1 maxTF=1 @{0 9427 5}
# unclear  -> term1274 Nt=7 TF=7 maxTF=1 @{0 9429 3}
# undergo  -> term1771 Nt=2 TF=2 maxTF=1 @{0 9435 5}
# undersid  -> term959 Nt=5 TF=9 maxTF=3 @{0 9437 7}
# understand  -> term503 Nt=8 TF=8 maxTF=1 @{0 9443 5}
# understood  -> term515 Nt=2 TF=2 maxTF=1 @{0 9450 5}
# uneven  -> term1617 Nt=3 TF=4 maxTF=2 @{0 9453 3}
# unexpectedli  -> term1841 Nt=1 TF=1 maxTF=1 @{0 9457 0}
# unfortun  -> term1696 Nt=2 TF=2 maxTF=1 @{0 9458 6}
# unicellular  -> term2109 Nt=1 TF=1 maxTF=1 @{0 9461 4}
# unit  -> term1826 Nt=1 TF=1 maxTF=1 @{0 9463 2}
# univers  -> term259 Nt=3 TF=10 maxTF=8 @{0 9465 0}
# unrecogniz  -> term1670 Nt=1 TF=1 maxTF=1 @{0 9469 5}
# unscrew  -> term2071 Nt=1 TF=2 maxTF=2 @{0 9471 3}
# unstabl  -> term1236 Nt=2 TF=2 maxTF=1 @{0 9473 2}
# untwist  -> term953 Nt=1 TF=1 maxTF=1 @{0 9476 2}
# unusu  -> term1006 Nt=3 TF=3 maxTF=1 @{0 9477 4}
# upcom  -> term1683 Nt=1 TF=1 maxTF=1 @{0 9481 4}
# uphil  -> term247 Nt=2 TF=2 maxTF=1 @{0 9483 2}
# upper  -> term597 Nt=4 TF=5 maxTF=2 @{0 9485 4}
# upright  -> term2018 Nt=2 TF=2 maxTF=1 @{0 9490 5}
# upsid  -> term1347 Nt=3 TF=3 maxTF=1 @{0 9493 1}
# upthrust  -> term1937 Nt=1 TF=2 maxTF=2 @{0 9496 5}
# upward  -> term739 Nt=7 TF=15 maxTF=4 @{0 9498 4}
# uranu  -> term1267 Nt=1 TF=3 maxTF=3 @{0 9506 4}
# us  -> term652 Nt=9 TF=10 maxTF=2 @{0 9508 2}
# usual  -> term2021 Nt=1 TF=1 maxTF=1 @{0 9515 7}
# usus  -> term1507 Nt=1 TF=1 maxTF=1 @{0 9517 5}
# util  -> term1952 Nt=1 TF=1 maxTF=1 @{0 9519 1}
# uv  -> term2227 Nt=1 TF=1 maxTF=1 @{0 9520 7}
# vacuol  -> term1951 Nt=1 TF=1 maxTF=1 @{0 9522 5}
# vacuum  -> term2136 Nt=1 TF=1 maxTF=1 @{0 9524 3}
# valv  -> term2206 Nt=1 TF=1 maxTF=1 @{0 9526 1}
# van  -> term1724 Nt=1 TF=2 maxTF=2 @{0 9527 7}
# vapor  -> term1105 Nt=14 TF=94 maxTF=34 @{0 9529 6}
# vari  -> term1289 Nt=5 TF=8 maxTF=4 @{0 9549 4}
# variant  -> term2232 Nt=1 TF=1 maxTF=1 @{0 9554 5}
# variat  -> term1276 Nt=1 TF=2 maxTF=2 @{0 9556 3}
# varieti  -> term1075 Nt=2 TF=2 maxTF=1 @{0 9558 0}
# vast  -> term1327 Nt=1 TF=1 maxTF=1 @{0 9561 2}
# ve  -> term1781 Nt=2 TF=2 maxTF=1 @{0 9562 6}
# veget  -> term592 Nt=1 TF=1 maxTF=1 @{0 9565 4}
# veloc  -> term2060 Nt=1 TF=1 maxTF=1 @{0 9566 6}
# venu  -> term1271 Nt=1 TF=5 maxTF=5 @{0 9568 4}
# vernal  -> term2236 Nt=1 TF=1 maxTF=1 @{0 9570 4}
# versa  -> term981 Nt=8 TF=8 maxTF=1 @{0 9572 2}
# version  -> term1886 Nt=1 TF=1 maxTF=1 @{0 9579 2}
# vertebr  -> term293 Nt=1 TF=1 maxTF=1 @{0 9581 0}
# vestibulo  -> term685 Nt=1 TF=1 maxTF=1 @{0 9581 6}
# vibrat  -> term479 Nt=8 TF=23 maxTF=6 @{0 9583 0}
# vice  -> term993 Nt=8 TF=8 maxTF=1 @{0 9592 7}
# vicin  -> term1611 Nt=2 TF=2 maxTF=1 @{0 9599 7}
# video  -> term1873 Nt=1 TF=1 maxTF=1 @{0 9603 1}
# view  -> term102 Nt=4 TF=4 maxTF=1 @{0 9604 7}
# vigor  -> term79 Nt=1 TF=1 maxTF=1 @{0 9609 3}
# vinegar  -> term297 Nt=3 TF=11 maxTF=4 @{0 9609 5}
# violent  -> term898 Nt=6 TF=6 maxTF=1 @{0 9614 3}
# virus  -> term600 Nt=1 TF=1 maxTF=1 @{0 9619 7}
# viscos  -> term1374 Nt=1 TF=3 maxTF=3 @{0 9621 1}
# viscou  -> term1377 Nt=1 TF=1 maxTF=1 @{0 9622 7}
# visibl  -> term532 Nt=16 TF=22 maxTF=6 @{0 9624 3}
# visit  -> term1296 Nt=1 TF=1 maxTF=1 @{0 9636 7}
# visitor  -> term1458 Nt=1 TF=1 maxTF=1 @{0 9638 3}
# vital  -> term914 Nt=1 TF=2 maxTF=2 @{0 9639 7}
# vocal  -> term1746 Nt=1 TF=1 maxTF=1 @{0 9641 2}
# void  -> term1528 Nt=3 TF=3 maxTF=1 @{0 9643 0}
# volatil  -> term1718 Nt=1 TF=2 maxTF=2 @{0 9646 6}
# volcano  -> term2131 Nt=1 TF=2 maxTF=2 @{0 9648 5}
# volum  -> term886 Nt=13 TF=37 maxTF=10 @{0 9650 4}
# vortex  -> term1888 Nt=1 TF=2 maxTF=2 @{0 9664 2}
# waal  -> term1702 Nt=1 TF=2 maxTF=2 @{0 9666 1}
# wai  -> term76 Nt=32 TF=38 maxTF=2 @{0 9668 0}
# wait  -> term1856 Nt=2 TF=4 maxTF=2 @{0 9686 2}
# wall  -> term434 Nt=11 TF=33 maxTF=9 @{0 9689 0}
# wander  -> term1855 Nt=1 TF=1 maxTF=1 @{0 9701 4}
# want  -> term121 Nt=11 TF=12 maxTF=2 @{0 9703 2}
# warm  -> term496 Nt=11 TF=12 maxTF=2 @{0 9712 1}
# warmer  -> term1078 Nt=4 TF=4 maxTF=1 @{0 9720 6}
# warmest  -> term1770 Nt=2 TF=2 maxTF=1 @{0 9726 0}
# warn  -> term2213 Nt=1 TF=1 maxTF=1 @{0 9729 0}
# warp  -> term2155 Nt=1 TF=1 maxTF=1 @{0 9730 6}
# warsaw  -> term1242 Nt=1 TF=1 maxTF=1 @{0 9732 4}
# wasn  -> term1446 Nt=1 TF=1 maxTF=1 @{0 9734 0}
# wast  -> term265 Nt=2 TF=2 maxTF=1 @{0 9735 4}
# water  -> term24 Nt=58 TF=713 maxTF=100 @{0 9738 0}
# watercolor  -> term1404 Nt=1 TF=1 maxTF=1 @{0 9842 1}
# wave  -> term485 Nt=7 TF=37 maxTF=9 @{0 9843 5}
# wavelength  -> term1077 Nt=4 TF=5 maxTF=2 @{0 9854 1}
# wax  -> term564 Nt=4 TF=20 maxTF=11 @{0 9859 2}
# weak  -> term1710 Nt=1 TF=2 maxTF=2 @{0 9865 4}
# weaker  -> term939 Nt=4 TF=4 maxTF=1 @{0 9867 3}
# weakli  -> term1714 Nt=1 TF=1 maxTF=1 @{0 9872 1}
# weather  -> term628 Nt=4 TF=4 maxTF=1 @{0 9873 7}
# wedg  -> term1554 Nt=1 TF=1 maxTF=1 @{0 9878 7}
# week  -> term1063 Nt=1 TF=1 maxTF=1 @{0 9880 3}
# weigh  -> term312 Nt=3 TF=5 maxTF=2 @{0 9881 7}
# weight  -> term331 Nt=4 TF=8 maxTF=3 @{0 9885 5}
# well  -> term70 Nt=29 TF=49 maxTF=5 @{0 9890 1}
# went  -> term1573 Nt=1 TF=1 maxTF=1 @{0 9908 3}
# wheat  -> term1392 Nt=2 TF=9 maxTF=8 @{0 9909 7}
# whei  -> term1043 Nt=1 TF=1 maxTF=1 @{0 9913 4}
# whirl  -> term1863 Nt=1 TF=5 maxTF=5 @{0 9915 0}
# whistl  -> term1099 Nt=1 TF=1 maxTF=1 @{0 9917 2}
# white  -> term271 Nt=7 TF=13 maxTF=5 @{0 9918 6}
# whizz  -> term1434 Nt=1 TF=1 maxTF=1 @{0 9926 2}
# who  -> term174 Nt=4 TF=4 maxTF=1 @{0 9927 6}
# whole  -> term935 Nt=9 TF=13 maxTF=3 @{0 9932 0}
# whoosh  -> term1851 Nt=1 TF=1 maxTF=1 @{0 9940 4}
# wick  -> term572 Nt=2 TF=18 maxTF=9 @{0 9942 2}
# wide  -> term867 Nt=2 TF=3 maxTF=2 @{0 9947 0}
# wider  -> term1098 Nt=5 TF=6 maxTF=2 @{0 9949 7}
# width  -> term1755 Nt=1 TF=1 maxTF=1 @{0 9955 4}
# wiggl  -> term1586 Nt=2 TF=3 maxTF=2 @{0 9957 2}
# wikipedia  -> term1297 Nt=2 TF=2 maxTF=1 @{0 9960 1}
# will  -> term217 Nt=74 TF=220 maxTF=10 @{0 9963 1}
# william  -> term1678 Nt=1 TF=1 maxTF=1 @{0 10006 5}
# wilt  -> term1406 Nt=1 TF=1 maxTF=1 @{0 10008 3}
# wind  -> term382 Nt=11 TF=16 maxTF=4 @{0 10009 7}
# windi  -> term1608 Nt=1 TF=1 maxTF=1 @{0 10019 6}
# wine  -> term2170 Nt=1 TF=1 maxTF=1 @{0 10021 4}
# wing  -> term973 Nt=1 TF=14 maxTF=14 @{0 10023 2}
# wink  -> term944 Nt=1 TF=1 maxTF=1 @{0 10026 1}
# winter  -> term1681 Nt=2 TF=5 maxTF=4 @{0 10027 3}
# wire  -> term644 Nt=4 TF=19 maxTF=9 @{0 10031 0}
# wisdom  -> term1487 Nt=1 TF=3 maxTF=3 @{0 10037 1}
# wish  -> term891 Nt=1 TF=1 maxTF=1 @{0 10038 7}
# withstand  -> term364 Nt=3 TF=3 maxTF=1 @{0 10040 1}
# wonder  -> term328 Nt=1 TF=1 maxTF=1 @{0 10043 7}
# wood  -> term745 Nt=3 TF=6 maxTF=4 @{0 10044 5}
# wooden  -> term800 Nt=1 TF=1 maxTF=1 @{0 10049 0}
# wool  -> term2118 Nt=1 TF=3 maxTF=3 @{0 10050 2}
# word  -> term942 Nt=3 TF=3 maxTF=1 @{0 10052 2}
# work  -> term34 Nt=37 TF=47 maxTF=4 @{0 10056 0}
# world  -> term1245 Nt=1 TF=1 maxTF=1 @{0 10075 0}
# worri  -> term421 Nt=1 TF=1 maxTF=1 @{0 10076 4}
# wors  -> term1850 Nt=1 TF=1 maxTF=1 @{0 10077 4}
# worst  -> term1143 Nt=2 TF=2 maxTF=1 @{0 10079 2}
# wound  -> term643 Nt=1 TF=1 maxTF=1 @{0 10082 2}
# wrap  -> term1224 Nt=4 TF=8 maxTF=4 @{0 10083 4}
# write  -> term1549 Nt=2 TF=2 maxTF=1 @{0 10088 2}
# wrote  -> term1842 Nt=1 TF=1 maxTF=1 @{0 10091 0}
# xanthophyl  -> term1958 Nt=1 TF=1 maxTF=1 @{0 10092 6}
# xylem  -> term1409 Nt=1 TF=3 maxTF=3 @{0 10094 4}
# xylophon  -> term2172 Nt=1 TF=1 maxTF=1 @{0 10096 2}
# ye  -> term1612 Nt=3 TF=3 maxTF=1 @{0 10098 0}
# year  -> term469 Nt=11 TF=29 maxTF=6 @{0 10101 2}
# yeast  -> term2101 Nt=1 TF=19 maxTF=19 @{0 10113 2}
# yellow  -> term1306 Nt=4 TF=6 maxTF=3 @{0 10117 2}
# yellowish  -> term1044 Nt=1 TF=1 maxTF=1 @{0 10121 4}
# yest  -> term2110 Nt=1 TF=1 maxTF=1 @{0 10123 0}
# yogurt  -> term1039 Nt=1 TF=19 maxTF=19 @{0 10124 6}
# yolk  -> term1786 Nt=1 TF=1 maxTF=1 @{0 10128 4}
# zone  -> term108 Nt=1 TF=3 maxTF=3 @{0 10130 2}

# %% [markdown]
# ### Query

# %%
# DEFINING HELPER FUNCTIONS

def get_exp_title(docid):
  id = int(docid[1:])
  return exp_title[id]

def get_exp_link(docid):
  id = int(docid[1:])
  return exp_link[id]

def get_exp_description(docid):
  id = int(docid[1:])
  return exp_desc[id]

def get_exp_subject(docid):
  id = int(docid[1:])
  return exp_subj[id]

def retrieve_exp_title(df):
  title = []
  link = []
  desc = []
  subject = []
  for i in range(df.shape[0]):
    docid = df.loc[i, 'docno']
    title.append(get_exp_title(docid))
    link.append(get_exp_link(docid))
    desc.append(get_exp_description(docid))
    subject.append(get_exp_subject(docid))
  df['Title'] = title
  df['Link'] = link
  df['Description'] = desc
  df['Subject'] = subject
  return df

# %%
br = pt.BatchRetrieve(index, wmodel="BM25")

queries = pd.DataFrame([["q1", "air baloon"], ["q2", "rocket yogurt"], ['q3', 'chemistry']], columns=["qid", "query"])
res = br(queries)
retrieve_exp_title(res)
# Out:
#    qid  docid docno  rank     score       query                    Title  \
# 0   q1     72   d72     0 -0.188022  air baloon  Special: Dust explosion
# 1   q1    105  d105     1 -0.188665  air baloon    Special: Colored fire
# 2   q1     86   d86     2 -0.222565  air baloon        Crystal egg geode
# 3   q1     85   d85     3 -0.234895  air baloon            Magic ice cut
# 4   q1     67   d67     4 -0.240533  air baloon      Salt water purifier
# ..  ..    ...   ...   ...       ...         ...                      ...
# 84  q3     40   d40    20  1.487716   chemistry    Bouncing soap bubbles
# 85  q3    105  d105    21  1.378235   chemistry    Special: Colored fire
# 86  q3     72   d72    22  1.373534   chemistry  Special: Dust explosion
# 87  q3     79   d79    23  1.279684   chemistry   Special: Whoosh bottle
# 88  q3     90   d90    24  0.573058   chemistry   Forever boiling bottle
#
#                                                  Link  \
# 0   https://www.experimentarchive.com/experiments/...
# 1   https://www.experimentarchive.com/experiments/...
# 2   https://www.experimentarchive.com/experiments/...
# 3   https://www.experimentarchive.com/experiments/...
# 4   https://www.experimentarchive.com/experiments/...
# ..                                                ...
# 84  https://www.experimentarchive.com/experiments/...
# 85  https://www.experimentarchive.com/experiments/...
# 86  https://www.experimentarchive.com/experiments/...
# 87  https://www.experimentarchive.com/experiments/...
# 88  https://www.experimentarchive.com/experiments/...
#
#                                           Description        Subject
# 0   Flour can be deadly. An experiment about chemi...      Chemistry
# 1   Create flames in a range of colors. About fire...      Chemistry
# 2   Make a lovely ornament with alum crystals. An ...  Earth science
# 3   Slice through ice. An experiment about heat an...      Chemistry
# 4   Turn salt water into drinking water. An experi...  Earth science
# ..                                                ...            ...
# 84  Hold a soap bubble in your hand. About polar a...      Chemistry
# 85  Create flames in a range of colors. About fire...      Chemistry
# 86  Flour can be deadly. An experiment about chemi...      Chemistry
# 87  Ignite ethanol to produce a pulsating, blue fi...      Chemistry
# 88  Water that boils at room temperature. About bo...      Chemistry
#
# [89 rows x 10 columns]

# %%
doc_list = res['docno'].tolist()

docs_df[docs_df['docno'].isin(doc_list)]
# Out:
#                        title        subject  \
# 0               Rainbow milk      Chemistry
# 2            Cartesian diver        Physics
# 3            Drops on a coin      Chemistry
# 4        Homemade marble run        Physics
# 6                Heavy paper  Earth science
# ..                       ...            ...
# 101            Orange candle      Chemistry
# 103     Water cycle in a jar  Earth science
# 104    Special: Fire bubbles        Physics
# 105    Special: Colored fire      Chemistry
# 107  Floating ping pong ball        Physics
#
#                                            description  \
# 0    Create a color explosion in milk. About polari...
# 2    Squeeze the bottle and the matches sink. About...
# 3    How many water drops can fit on a coin? About ...
# 4    Build a marble run on the wall. About gravitat...
# 6    Break a ruler using a newspaper. An experiment...
# ..                                                 ...
# 101  Turn an orange into a candle. An experiment ab...
# 103   Recreate most of the water cycle in a glass jar.
# 104  Hold fire in your hand. An experiment about en...
# 105  Create flames in a range of colors. About fire...
# 107  Float a ball above your science hairdryer. Abo...
#
#                                                   link  \
# 0    https://www.experimentarchive.com/experiments/...
# 2    https://www.experimentarchive.com/experiments/...
# 3    https://www.experimentarchive.com/experiments/...
# 4    https://www.experimentarchive.com/experiments/...
# 6    https://www.experimentarchive.com/experiments/...
# ..                                                 ...
# 101  https://www.experimentarchive.com/experiments/...
# 103  https://www.experimentarchive.com/experiments/...
# 104  https://www.experimentarchive.com/experiments/...
# 105  https://www.experimentarchive.com/experiments/...
# 107  https://www.experimentarchive.com/experiments/...
#
#                                            explanation docno  \
# 0    Milk is a mixture consisting of water and chem...    d0
# 2    The head of a match is porous and contains sma...    d2
# 3    Water consists of water molecules that attract...    d3
# 4    The higher up something is, the more gravitati...    d4
# 6    It's not the newspaper that is heavy enough to...    d6
# ..                                                 ...   ...
# 101  The orange candle works just like a normal can...  d101
# 103  When you pour water into the jar, some of the ...  d103
# 104  The aerosol spray bottle is an ingenious inven...  d104
# 105  The color of a flame depends mainly on two thi...  d105
# 107  This experiment illustrates Bernouille's princ...  d107
#
#                                                   text
# 0    Rainbow milk Chemistry Milk is a mixture consi...
# 2    Cartesian diver Physics The head of a match is...
# 3    Drops on a coin Chemistry Water consists of wa...
# 4    Homemade marble run Physics The higher up some...
# 6    Heavy paper Earth science It's not the newspap...
# ..                                                 ...
# 101  Orange candle Chemistry The orange candle work...
# 103  Water cycle in a jar Earth science When you po...
# 104  Special: Fire bubbles Physics The aerosol spra...
# 105  Special: Colored fire Chemistry The color of a...
# 107  Floating ping pong ball Physics This experimen...
#
# [69 rows x 7 columns]
